# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Compose
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import sklearn as skl
import pandas as pd
#from torchviz import make_dot
import torch.optim as optim
from collections import defaultdict
import pickle
import dill
import json
import datetime
try:
    import google.colab
    from google.colab import files  
    COLAB = True
except:
    COLAB = False

# %%
#Como siempre chequeamos que este el GPU o el CPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Usando el dispositivo {}'.format(device))
# Out:
# Usando el dispositivo cpu

# %%
# Cargamos los datos de FASHION-MNIST
train_dataset = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)
test_dataset = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %%
class ShowImage(Dataset):
    def __init__(self,dataset):
        self.dataset=dataset
    def __len__(self):
        return len(self.dataset)
    def __getitem__(self,i):
        image,label=self.dataset[i]
        label=torch.flatten(image)
        return image,label

# %%
train_dataset=ShowImage(train_dataset)
test_dataset=ShowImage(test_dataset)
len(train_dataset), len(test_dataset)
# Out:
# (60000, 10000)

# %%
class Autoencoder(nn.Module):
    def __init__(self,n=64,p=0.1):
        super().__init__()        
        self.encoder = torch.nn.Sequential(
            nn.Flatten(),
            nn.Linear(28*28, n),
            nn.Dropout(p),
            nn.ReLU(),
            #nn.Linear(n, n)
        )
          
        self.decoder = torch.nn.Sequential(
            nn.Dropout(p),
            nn.ReLU(),
            nn.Linear(n,28*28)
        )
  
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded
  
# Instantiating the model and hyperparameters
#model = Autoencoder()
#criterion = torch.nn.MSELoss()
#num_epochs = 100
#optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
model=Autoencoder().to(device)
print(model)
# Out:
# Autoencoder(
#   (encoder): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=784, out_features=64, bias=True)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): ReLU()
#   )
#   (decoder): Sequential(
#     (0): Dropout(p=0.1, inplace=False)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=784, bias=True)
#   )
# )

# %%
# Definimos la función de entrenamiento
def train_loop(dataloader,model,loss_fn,optimizer,verbose_each=32):  
    # Calculamos cosas utiles que necesitamos
    num_samples = len(dataloader.dataset) #numero de muestras de entrenamiento
    # Seteamos el modelo en modo entrenamiento. Esto sirve para activar, por ejemplo, dropout, etc. durante la fase de entrenamiento.
    model.train()
    # Pasamos el modelo a la GPU si está disponible.        
    model = model.to(device)    
    # Iteramos sobre lotes (batchs)
    for batch,(X,y) in enumerate(dataloader):
        # Pasamos los tensores a la GPU si está disponible.
        X = X.to(device)
        y = y.to(device)      
        # Calculamos la predicción del modelo y la correspondiente pérdida (error)
        pred = model(X)
        loss = loss_fn(pred,y)
        # Backpropagamos usando el optimizador proveido.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Imprimimos el progreso cada 100 batchs
        if batch % verbose_each*len(X) == 0:
            loss   = loss.item()
            sample = batch*len(X) # Número de batch * número de muestras en cada batch
            #print(f"batch={batch} loss={loss:>7f}  muestras-procesadas:[{sample:>5d}/{num_samples:>5d}]")            
# De manera similar, definimos la función de validación y testeo
def test_loop(dataloader,model,loss_fn):
    num_samples  = len(dataloader.dataset)
    num_batches  = len(dataloader)
    avrg_loss    = 0
    frac_correct = 0
    # Seteamos el modelo en modo evaluacion. Esto sirve para desactivar, por ejemplo, dropout, etc. cuando no estamos en una fase de entrenamiento.
    model.eval()
    # Pasamos el modelo la GPU si está disponible.    
    model = model.to(device)    
    # Para validar, desactivamos el cálculo de gradientes.
    with torch.no_grad():
        # Iteramos sobre lotes (batches)
        for X,y in dataloader:
            # Pasamos los tensores a la GPU si está disponible.
            X = X.to(device)
            y = y.to(device)           
            # Calculamos las predicciones del modelo...
            pred = model(X)
            # y las correspondientes pérdidas (errores), los cuales vamos acumulando en un valor total.
            num_batches += 1
            avrg_loss += loss_fn(pred,y).item()
            # También calculamos el número de predicciones correctas, y lo acumulamos en un total.
            #num_samples += y.size(0)            
            #frac_correct += (pred.argmax(1)==y).type(torch.float).sum().item()
    # Calculamos la pérdida total y la fracción de clasificaciones correctas, y las imprimimos.
    avrg_loss    /= num_batches
    frac_correct /= num_samples
    #print(f"Test Error: \n Accuracy: {frac_correct:>0.5f}, Avg. loss: {avrg_loss:>8f} \n")
    return avrg_loss,frac_correct

# %%
# Definimos hiperparámetros de entrenamiento
learning_rate = 1e-3
batch_size = 1000
num_epochs = 200
num_k = 1 #72
#n=64

# Creamos una funcion de perdida
loss_fn = nn.MSELoss()
# Creamos un DataFrame de pandas para ir almacenando los valores calculados.
df = pd.DataFrame()
# Simulamos por tramos porque google colab se desconecta antes de que concluya para todos los valores de n en la lista.

sizes=[64,128,256,512]
for n in sizes:
#for k in range(num_k):
    # Creamos el modelo y el optimzador
    model = Autoencoder(n)
    # Creamos los dataloaders ...
    train_dataloader = DataLoader(train_dataset,batch_size=batch_size)
    # ... en particular, usamos el dataset de prueba (test) como dataset de validación
    valid_dataloader = DataLoader(test_dataset,batch_size=batch_size)         
    #optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate)
    optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate,eps=1e-08,weight_decay=0,amsgrad=False)
    # Entrenamos el modelo y calcualmos curvas.
    min_valid_loss = float("inf")
    for epoch in range(num_epochs):
        train_loop(train_dataloader,model,loss_fn,optimizer)
        train_loss,train_accu = test_loop(train_dataloader,model,loss_fn)
        valid_loss,valid_accu = test_loop(valid_dataloader,model,loss_fn)
        print(f"n={n} k={k} epoch={epoch} train_loss={train_loss} train_accu={train_accu} valid_loss={valid_loss} valid_accu={valid_accu}")
        df = df.append({"n":n,
                        "k":k,
                        "epoch":epoch,
                        "train_loss":train_loss,
                        "train_accu":train_accu,
                        "valid_loss":valid_loss,
                        "valid_accu":valid_accu}
                        ,ignore_index=True)
json_fname = "simulation-results-"+datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+".json"
df.to_json(json_fname)
if COLAB:
    files.download(json_fname)
# Out:
# n=64 k=0 epoch=0 train_loss=0.02719458220526576 train_accu=0.0 valid_loss=0.02706148810684681 valid_accu=0.0
# n=64 k=0 epoch=1 train_loss=0.01982426382601261 train_accu=0.0 valid_loss=0.01974471043795347 valid_accu=0.0
# n=64 k=0 epoch=2 train_loss=0.016326037514954806 train_accu=0.0 valid_loss=0.016273358650505543 valid_accu=0.0
# n=64 k=0 epoch=3 train_loss=0.014754672643418114 train_accu=0.0 valid_loss=0.014709376823157072 valid_accu=0.0
# n=64 k=0 epoch=4 train_loss=0.014069004341339071 train_accu=0.0 valid_loss=0.014031681790947914 valid_accu=0.0
# n=64 k=0 epoch=5 train_loss=0.013405281165614725 train_accu=0.0 valid_loss=0.01337181283161044 valid_accu=0.0
# n=64 k=0 epoch=6 train_loss=0.01306887911632657 train_accu=0.0 valid_loss=0.013045922294259072 valid_accu=0.0
# n=64 k=0 epoch=7 train_loss=0.012337076927845676 train_accu=0.0 valid_loss=0.012314737495034932 valid_accu=0.0
# n=64 k=0 epoch=8 train_loss=0.011976261856034398 train_accu=0.0 valid_loss=0.011955942772328854 valid_accu=0.0
# n=64 k=0 epoch=9 train_loss=0.01179384432422618 train_accu=0.0 valid_loss=0.011777417920529842 valid_accu=0.0
# n=64 k=0 epoch=10 train_loss=0.011495466716587544 train_accu=0.0 valid_loss=0.011481358855962753 valid_accu=0.0
# n=64 k=0 epoch=11 train_loss=0.011218795971944927 train_accu=0.0 valid_loss=0.011206024046987294 valid_accu=0.0
# n=64 k=0 epoch=12 train_loss=0.011049324832856654 train_accu=0.0 valid_loss=0.011037780903279781 valid_accu=0.0
# n=64 k=0 epoch=13 train_loss=0.010895373485982417 train_accu=0.0 valid_loss=0.010885967407375574 valid_accu=0.0
# n=64 k=0 epoch=14 train_loss=0.010799415859704216 train_accu=0.0 valid_loss=0.01079176627099514 valid_accu=0.0
# n=64 k=0 epoch=15 train_loss=0.010886882819856206 train_accu=0.0 valid_loss=0.010880787298083306 valid_accu=0.0
# n=64 k=0 epoch=16 train_loss=0.010604900509739916 train_accu=0.0 valid_loss=0.010597563907504081 valid_accu=0.0
# n=64 k=0 epoch=17 train_loss=0.010616434303422769 train_accu=0.0 valid_loss=0.010610172525048256 valid_accu=0.0
# n=64 k=0 epoch=18 train_loss=0.010677193167308967 train_accu=0.0 valid_loss=0.010673162806779147 valid_accu=0.0
# n=64 k=0 epoch=19 train_loss=0.010577514752124746 train_accu=0.0 valid_loss=0.010574283916503191 valid_accu=0.0
# n=64 k=0 epoch=20 train_loss=0.01043082143490513 train_accu=0.0 valid_loss=0.0104267624206841 valid_accu=0.0
# n=64 k=0 epoch=21 train_loss=0.010537003663678964 train_accu=0.0 valid_loss=0.010534962266683578 valid_accu=0.0
# n=64 k=0 epoch=22 train_loss=0.010539781162515282 train_accu=0.0 valid_loss=0.010537841357290745 valid_accu=0.0
# n=64 k=0 epoch=23 train_loss=0.010266485329096516 train_accu=0.0 valid_loss=0.010262738354504109 valid_accu=0.0
# n=64 k=0 epoch=24 train_loss=0.01025612346517543 train_accu=0.0 valid_loss=0.010252868756651878 valid_accu=0.0
# n=64 k=0 epoch=25 train_loss=0.010310596600174905 train_accu=0.0 valid_loss=0.010306838527321815 valid_accu=0.0
# n=64 k=0 epoch=26 train_loss=0.01018297386666139 train_accu=0.0 valid_loss=0.010180447716265917 valid_accu=0.0
# n=64 k=0 epoch=27 train_loss=0.010419360765566429 train_accu=0.0 valid_loss=0.010417169611901044 valid_accu=0.0
# n=64 k=0 epoch=28 train_loss=0.010308365446204941 train_accu=0.0 valid_loss=0.010306324530392885 valid_accu=0.0
# n=64 k=0 epoch=29 train_loss=0.010098595141122739 train_accu=0.0 valid_loss=0.010094845946878196 valid_accu=0.0
# n=64 k=0 epoch=30 train_loss=0.010081243002787232 train_accu=0.0 valid_loss=0.010078700818121433 valid_accu=0.0
# n=64 k=0 epoch=31 train_loss=0.010040151017407576 train_accu=0.0 valid_loss=0.010036911629140378 valid_accu=0.0
# n=64 k=0 epoch=32 train_loss=0.010037071149175366 train_accu=0.0 valid_loss=0.010032525565475226 valid_accu=0.0
# n=64 k=0 epoch=33 train_loss=0.010282793004686633 train_accu=0.0 valid_loss=0.010280334390699863 valid_accu=0.0
# n=64 k=0 epoch=34 train_loss=0.010200489001969496 train_accu=0.0 valid_loss=0.010196027625352145 valid_accu=0.0
# n=64 k=0 epoch=35 train_loss=0.009980917939295371 train_accu=0.0 valid_loss=0.009977320302277803 valid_accu=0.0
# n=64 k=0 epoch=36 train_loss=0.010307593069349726 train_accu=0.0 valid_loss=0.010305166523903609 valid_accu=0.0
# n=64 k=0 epoch=37 train_loss=0.010080416034907103 train_accu=0.0 valid_loss=0.010077634640038014 valid_accu=0.0
# n=64 k=0 epoch=38 train_loss=0.010057108523324133 train_accu=0.0 valid_loss=0.010054140351712704 valid_accu=0.0
# n=64 k=0 epoch=39 train_loss=0.010007752183203896 train_accu=0.0 valid_loss=0.01000394243746996 valid_accu=0.0
# n=64 k=0 epoch=40 train_loss=0.009982382350911697 train_accu=0.0 valid_loss=0.009979328140616417 valid_accu=0.0
# n=64 k=0 epoch=41 train_loss=0.01000450481660664 train_accu=0.0 valid_loss=0.010001226421445608 valid_accu=0.0
# n=64 k=0 epoch=42 train_loss=0.009945354331284762 train_accu=0.0 valid_loss=0.009943071007728576 valid_accu=0.0
# n=64 k=0 epoch=43 train_loss=0.01000930912171801 train_accu=0.0 valid_loss=0.01000549616292119 valid_accu=0.0
# n=64 k=0 epoch=44 train_loss=0.010201302403584123 train_accu=0.0 valid_loss=0.010199770517647266 valid_accu=0.0
# n=64 k=0 epoch=45 train_loss=0.010069091540450851 train_accu=0.0 valid_loss=0.010068334452807904 valid_accu=0.0
# n=64 k=0 epoch=46 train_loss=0.010209748878454168 train_accu=0.0 valid_loss=0.010207757726311684 valid_accu=0.0
# n=64 k=0 epoch=47 train_loss=0.010078012462084491 train_accu=0.0 valid_loss=0.010076766647398473 valid_accu=0.0
# n=64 k=0 epoch=48 train_loss=0.010019249080990751 train_accu=0.0 valid_loss=0.0100177519954741 valid_accu=0.0
# n=64 k=0 epoch=49 train_loss=0.01007702377003928 train_accu=0.0 valid_loss=0.010074072703719138 valid_accu=0.0
# n=64 k=0 epoch=50 train_loss=0.009934006879727045 train_accu=0.0 valid_loss=0.009930886980146169 valid_accu=0.0
# n=64 k=0 epoch=51 train_loss=0.009951281423370043 train_accu=0.0 valid_loss=0.009948654286563396 valid_accu=0.0
# n=64 k=0 epoch=52 train_loss=0.009894042384500305 train_accu=0.0 valid_loss=0.00989273451268673 valid_accu=0.0
# n=64 k=0 epoch=53 train_loss=0.010127300939833125 train_accu=0.0 valid_loss=0.010126992221921682 valid_accu=0.0
# n=64 k=0 epoch=54 train_loss=0.01012432739759485 train_accu=0.0 valid_loss=0.010123858600854874 valid_accu=0.0
# n=64 k=0 epoch=55 train_loss=0.009937858038271467 train_accu=0.0 valid_loss=0.009938211459666491 valid_accu=0.0
# n=64 k=0 epoch=56 train_loss=0.010003392910584807 train_accu=0.0 valid_loss=0.010003104340285063 valid_accu=0.0
# n=64 k=0 epoch=57 train_loss=0.009891155268996954 train_accu=0.0 valid_loss=0.009888676926493645 valid_accu=0.0
# n=64 k=0 epoch=58 train_loss=0.010074603697285056 train_accu=0.0 valid_loss=0.010073656402528285 valid_accu=0.0
# n=64 k=0 epoch=59 train_loss=0.009912644807870189 train_accu=0.0 valid_loss=0.009911265596747399 valid_accu=0.0
# n=64 k=0 epoch=60 train_loss=0.009948063269257545 train_accu=0.0 valid_loss=0.009947979915887117 valid_accu=0.0
# n=64 k=0 epoch=61 train_loss=0.00985767178547879 train_accu=0.0 valid_loss=0.00985600594431162 valid_accu=0.0
# n=64 k=0 epoch=62 train_loss=0.009927530105536183 train_accu=0.0 valid_loss=0.009926224127411842 valid_accu=0.0
# n=64 k=0 epoch=63 train_loss=0.010020908170069258 train_accu=0.0 valid_loss=0.010018079448491335 valid_accu=0.0
# n=64 k=0 epoch=64 train_loss=0.009912852616980671 train_accu=0.0 valid_loss=0.009911789745092391 valid_accu=0.0
# n=64 k=0 epoch=65 train_loss=0.00987004991620779 train_accu=0.0 valid_loss=0.009868497587740421 valid_accu=0.0
# n=64 k=0 epoch=66 train_loss=0.00986605933867395 train_accu=0.0 valid_loss=0.009864063002169132 valid_accu=0.0
# n=64 k=0 epoch=67 train_loss=0.009999778975422183 train_accu=0.0 valid_loss=0.010000711772590876 valid_accu=0.0
# n=64 k=0 epoch=68 train_loss=0.00984920347109437 train_accu=0.0 valid_loss=0.009848103299736977 valid_accu=0.0
# n=64 k=0 epoch=69 train_loss=0.01000039513843755 train_accu=0.0 valid_loss=0.010000540502369403 valid_accu=0.0
# n=64 k=0 epoch=70 train_loss=0.009909425272295873 train_accu=0.0 valid_loss=0.00990717513486743 valid_accu=0.0
# n=64 k=0 epoch=71 train_loss=0.009886747412383556 train_accu=0.0 valid_loss=0.009885583817958832 valid_accu=0.0
# n=64 k=0 epoch=72 train_loss=0.009861424254874388 train_accu=0.0 valid_loss=0.00986085282638669 valid_accu=0.0
# n=64 k=0 epoch=73 train_loss=0.009899420104920864 train_accu=0.0 valid_loss=0.009897314384579659 valid_accu=0.0
# n=64 k=0 epoch=74 train_loss=0.009877142092833916 train_accu=0.0 valid_loss=0.009877696819603442 valid_accu=0.0
# n=64 k=0 epoch=75 train_loss=0.00987074845470488 train_accu=0.0 valid_loss=0.00987070370465517 valid_accu=0.0
# n=64 k=0 epoch=76 train_loss=0.009890841335679095 train_accu=0.0 valid_loss=0.00989058604463935 valid_accu=0.0
# n=64 k=0 epoch=77 train_loss=0.009907046317433317 train_accu=0.0 valid_loss=0.009907770715653897 valid_accu=0.0
# n=64 k=0 epoch=78 train_loss=0.010009323184688886 train_accu=0.0 valid_loss=0.010008879750967026 valid_accu=0.0
# n=64 k=0 epoch=79 train_loss=0.009832152817398309 train_accu=0.0 valid_loss=0.009831772278994321 valid_accu=0.0
# n=64 k=0 epoch=80 train_loss=0.009812649292871355 train_accu=0.0 valid_loss=0.009813390951603652 valid_accu=0.0
# n=64 k=0 epoch=81 train_loss=0.00988490389039119 train_accu=0.0 valid_loss=0.009886085893958807 valid_accu=0.0
# n=64 k=0 epoch=82 train_loss=0.0100600965321064 train_accu=0.0 valid_loss=0.010059365537017584 valid_accu=0.0
# n=64 k=0 epoch=83 train_loss=0.010034254984930158 train_accu=0.0 valid_loss=0.010036198142915963 valid_accu=0.0
# n=64 k=0 epoch=84 train_loss=0.009970391464109222 train_accu=0.0 valid_loss=0.009971436485648156 valid_accu=0.0
# n=64 k=0 epoch=85 train_loss=0.009848406724631786 train_accu=0.0 valid_loss=0.00985036138445139 valid_accu=0.0
# n=64 k=0 epoch=86 train_loss=0.00984508126663665 train_accu=0.0 valid_loss=0.00984662976115942 valid_accu=0.0
# n=64 k=0 epoch=87 train_loss=0.009824628538141648 train_accu=0.0 valid_loss=0.009827415086328983 valid_accu=0.0
# n=64 k=0 epoch=88 train_loss=0.009903645205001036 train_accu=0.0 valid_loss=0.009907674416899681 valid_accu=0.0
# n=64 k=0 epoch=89 train_loss=0.009975418898587425 train_accu=0.0 valid_loss=0.009981832932680845 valid_accu=0.0
# n=64 k=0 epoch=90 train_loss=0.00995558964399 train_accu=0.0 valid_loss=0.009959962405264377 valid_accu=0.0
# n=64 k=0 epoch=91 train_loss=0.00980664899883171 train_accu=0.0 valid_loss=0.009810743387788534 valid_accu=0.0
# n=64 k=0 epoch=92 train_loss=0.009869199618697167 train_accu=0.0 valid_loss=0.009874018095433711 valid_accu=0.0
# n=64 k=0 epoch=93 train_loss=0.009808099269866944 train_accu=0.0 valid_loss=0.00981394574046135 valid_accu=0.0
# n=64 k=0 epoch=94 train_loss=0.009854818290720383 train_accu=0.0 valid_loss=0.009859408624470234 valid_accu=0.0
# n=64 k=0 epoch=95 train_loss=0.009885282473017771 train_accu=0.0 valid_loss=0.009890273306518793 valid_accu=0.0
# n=64 k=0 epoch=96 train_loss=0.00988352025548617 train_accu=0.0 valid_loss=0.009888257551938295 valid_accu=0.0
# n=64 k=0 epoch=97 train_loss=0.009862289670854807 train_accu=0.0 valid_loss=0.009868650510907174 valid_accu=0.0
# n=64 k=0 epoch=98 train_loss=0.009887335154538353 train_accu=0.0 valid_loss=0.009897533152252436 valid_accu=0.0
# n=64 k=0 epoch=99 train_loss=0.009999042470008134 train_accu=0.0 valid_loss=0.010011929832398892 valid_accu=0.0
# n=64 k=0 epoch=100 train_loss=0.009777791456629832 train_accu=0.0 valid_loss=0.009790443908423185 valid_accu=0.0
# n=64 k=0 epoch=101 train_loss=0.009798810041199127 train_accu=0.0 valid_loss=0.009810024965554475 valid_accu=0.0
# n=64 k=0 epoch=102 train_loss=0.009868164841706554 train_accu=0.0 valid_loss=0.009878875967115164 valid_accu=0.0
# n=64 k=0 epoch=103 train_loss=0.00974933843438824 train_accu=0.0 valid_loss=0.009761530347168446 valid_accu=0.0
# n=64 k=0 epoch=104 train_loss=0.009773171367123723 train_accu=0.0 valid_loss=0.009785923175513744 valid_accu=0.0
# n=64 k=0 epoch=105 train_loss=0.009806140155221025 train_accu=0.0 valid_loss=0.00981742488220334 valid_accu=0.0
# n=64 k=0 epoch=106 train_loss=0.009782460611313581 train_accu=0.0 valid_loss=0.009794238582253456 valid_accu=0.0
# n=64 k=0 epoch=107 train_loss=0.009758963653196891 train_accu=0.0 valid_loss=0.009771160874515772 valid_accu=0.0
# n=64 k=0 epoch=108 train_loss=0.00971468212082982 train_accu=0.0 valid_loss=0.009726288262754679 valid_accu=0.0
# n=64 k=0 epoch=109 train_loss=0.00970506736387809 train_accu=0.0 valid_loss=0.009716088138520717 valid_accu=0.0
# n=64 k=0 epoch=110 train_loss=0.009722206912313899 train_accu=0.0 valid_loss=0.009734409023076296 valid_accu=0.0
# n=64 k=0 epoch=111 train_loss=0.009825372649356724 train_accu=0.0 valid_loss=0.009836041554808616 valid_accu=0.0
# n=64 k=0 epoch=112 train_loss=0.00974454153329134 train_accu=0.0 valid_loss=0.009756074845790863 valid_accu=0.0
# n=64 k=0 epoch=113 train_loss=0.009826708926508824 train_accu=0.0 valid_loss=0.00983616542071104 valid_accu=0.0
# n=64 k=0 epoch=114 train_loss=0.009732887816304962 train_accu=0.0 valid_loss=0.00974326003342867 valid_accu=0.0
# n=64 k=0 epoch=115 train_loss=0.009695998750006159 train_accu=0.0 valid_loss=0.009705752599984407 valid_accu=0.0
# n=64 k=0 epoch=116 train_loss=0.009768286192168792 train_accu=0.0 valid_loss=0.009779638890177012 valid_accu=0.0
# n=64 k=0 epoch=117 train_loss=0.009759648020068805 train_accu=0.0 valid_loss=0.009770840220153332 valid_accu=0.0
# n=64 k=0 epoch=118 train_loss=0.009754966897889971 train_accu=0.0 valid_loss=0.00976590123027563 valid_accu=0.0
# n=64 k=0 epoch=119 train_loss=0.009712504874914884 train_accu=0.0 valid_loss=0.009723994228988887 valid_accu=0.0
# n=64 k=0 epoch=120 train_loss=0.009685803096120556 train_accu=0.0 valid_loss=0.009696542657911778 valid_accu=0.0
# n=64 k=0 epoch=121 train_loss=0.00965695564324657 train_accu=0.0 valid_loss=0.009669538121670485 valid_accu=0.0
# n=64 k=0 epoch=122 train_loss=0.009750918842231233 train_accu=0.0 valid_loss=0.009763580281287432 valid_accu=0.0
# n=64 k=0 epoch=123 train_loss=0.009671890130266547 train_accu=0.0 valid_loss=0.009682593867182732 valid_accu=0.0
# n=64 k=0 epoch=124 train_loss=0.009713057366510233 train_accu=0.0 valid_loss=0.009725789725780486 valid_accu=0.0
# n=64 k=0 epoch=125 train_loss=0.0097519904995958 train_accu=0.0 valid_loss=0.009763486031442881 valid_accu=0.0
# n=64 k=0 epoch=126 train_loss=0.009693209609637658 train_accu=0.0 valid_loss=0.009704632125794888 valid_accu=0.0
# n=64 k=0 epoch=127 train_loss=0.009669614396989346 train_accu=0.0 valid_loss=0.00968318860977888 valid_accu=0.0
# n=64 k=0 epoch=128 train_loss=0.009713777806609869 train_accu=0.0 valid_loss=0.009726959466934203 valid_accu=0.0
# n=64 k=0 epoch=129 train_loss=0.009718750137835741 train_accu=0.0 valid_loss=0.009731251187622547 valid_accu=0.0
# n=64 k=0 epoch=130 train_loss=0.009784172490860025 train_accu=0.0 valid_loss=0.009796353708952665 valid_accu=0.0
# n=64 k=0 epoch=131 train_loss=0.009654181947310766 train_accu=0.0 valid_loss=0.00966703025624156 valid_accu=0.0
# n=64 k=0 epoch=132 train_loss=0.009753999393433332 train_accu=0.0 valid_loss=0.009767155069857836 valid_accu=0.0
# n=64 k=0 epoch=133 train_loss=0.009830718751375873 train_accu=0.0 valid_loss=0.00984594477340579 valid_accu=0.0
# n=64 k=0 epoch=134 train_loss=0.009709646351014574 train_accu=0.0 valid_loss=0.009723653830587865 valid_accu=0.0
# n=64 k=0 epoch=135 train_loss=0.00981208134132127 train_accu=0.0 valid_loss=0.009826256148517131 valid_accu=0.0
# n=64 k=0 epoch=136 train_loss=0.009756266543020805 train_accu=0.0 valid_loss=0.00977137591689825 valid_accu=0.0
# n=64 k=0 epoch=137 train_loss=0.009857456681008141 train_accu=0.0 valid_loss=0.009872331097722054 valid_accu=0.0
# n=64 k=0 epoch=138 train_loss=0.009728166336814562 train_accu=0.0 valid_loss=0.009741987287998199 valid_accu=0.0
# n=64 k=0 epoch=139 train_loss=0.009806901899476845 train_accu=0.0 valid_loss=0.00982025507837534 valid_accu=0.0
# n=64 k=0 epoch=140 train_loss=0.009744300553575159 train_accu=0.0 valid_loss=0.009758432768285275 valid_accu=0.0
# n=64 k=0 epoch=141 train_loss=0.009755830808232228 train_accu=0.0 valid_loss=0.009770876169204712 valid_accu=0.0
# n=64 k=0 epoch=142 train_loss=0.009753085626289248 train_accu=0.0 valid_loss=0.009765319898724556 valid_accu=0.0
# n=64 k=0 epoch=143 train_loss=0.009668508001292745 train_accu=0.0 valid_loss=0.009683368634432555 valid_accu=0.0
# n=64 k=0 epoch=144 train_loss=0.009737561224028468 train_accu=0.0 valid_loss=0.00975180435925722 valid_accu=0.0
# n=64 k=0 epoch=145 train_loss=0.009835670748725534 train_accu=0.0 valid_loss=0.009851994644850492 valid_accu=0.0
# n=64 k=0 epoch=146 train_loss=0.0097016340897729 train_accu=0.0 valid_loss=0.009716413635760545 valid_accu=0.0
# n=64 k=0 epoch=147 train_loss=0.009708665776997805 train_accu=0.0 valid_loss=0.009723135177046061 valid_accu=0.0
# n=64 k=0 epoch=148 train_loss=0.009675279756387075 train_accu=0.0 valid_loss=0.009690332133322955 valid_accu=0.0
# n=64 k=0 epoch=149 train_loss=0.009727390219147007 train_accu=0.0 valid_loss=0.009740784391760826 valid_accu=0.0
# n=64 k=0 epoch=150 train_loss=0.009694480740775665 train_accu=0.0 valid_loss=0.009708113875240088 valid_accu=0.0
# n=64 k=0 epoch=151 train_loss=0.009761505651598175 train_accu=0.0 valid_loss=0.009774410724639892 valid_accu=0.0
# n=64 k=0 epoch=152 train_loss=0.009682748947913449 train_accu=0.0 valid_loss=0.009695765655487775 valid_accu=0.0
# n=64 k=0 epoch=153 train_loss=0.009731772091860573 train_accu=0.0 valid_loss=0.009745103679597378 valid_accu=0.0
# n=64 k=0 epoch=154 train_loss=0.00969030534227689 train_accu=0.0 valid_loss=0.009702871553599834 valid_accu=0.0
# n=64 k=0 epoch=155 train_loss=0.00974960601888597 train_accu=0.0 valid_loss=0.009764354396611451 valid_accu=0.0
# n=64 k=0 epoch=156 train_loss=0.009923717674488823 train_accu=0.0 valid_loss=0.009937756508588792 valid_accu=0.0
# n=64 k=0 epoch=157 train_loss=0.009780594535792867 train_accu=0.0 valid_loss=0.00979686714708805 valid_accu=0.0
# n=64 k=0 epoch=158 train_loss=0.00973964836448431 train_accu=0.0 valid_loss=0.00975442323833704 valid_accu=0.0
# n=64 k=0 epoch=159 train_loss=0.009759447304531932 train_accu=0.0 valid_loss=0.009774201642721891 valid_accu=0.0
# n=64 k=0 epoch=160 train_loss=0.0096623999842753 train_accu=0.0 valid_loss=0.009677003510296345 valid_accu=0.0
# n=64 k=0 epoch=161 train_loss=0.009753434111674626 train_accu=0.0 valid_loss=0.009769652038812637 valid_accu=0.0
# n=64 k=0 epoch=162 train_loss=0.009697379653031628 train_accu=0.0 valid_loss=0.009712394699454308 valid_accu=0.0
# n=64 k=0 epoch=163 train_loss=0.009730069137488803 train_accu=0.0 valid_loss=0.009744301158934831 valid_accu=0.0
# n=64 k=0 epoch=164 train_loss=0.009710251353681087 train_accu=0.0 valid_loss=0.009726996161043644 valid_accu=0.0
# n=64 k=0 epoch=165 train_loss=0.009782173701872428 train_accu=0.0 valid_loss=0.009796792361885309 valid_accu=0.0
# n=64 k=0 epoch=166 train_loss=0.009660749323666095 train_accu=0.0 valid_loss=0.00967502212151885 valid_accu=0.0
# n=64 k=0 epoch=167 train_loss=0.009709520048151414 train_accu=0.0 valid_loss=0.009722002781927586 valid_accu=0.0
# n=64 k=0 epoch=168 train_loss=0.009653538574154179 train_accu=0.0 valid_loss=0.009668406657874584 valid_accu=0.0
# n=64 k=0 epoch=169 train_loss=0.00978375831618905 train_accu=0.0 valid_loss=0.009799619764089584 valid_accu=0.0
# n=64 k=0 epoch=170 train_loss=0.00975285805761814 train_accu=0.0 valid_loss=0.009768444858491421 valid_accu=0.0
# n=64 k=0 epoch=171 train_loss=0.009733405010774732 train_accu=0.0 valid_loss=0.009748684242367744 valid_accu=0.0
# n=64 k=0 epoch=172 train_loss=0.00971273115525643 train_accu=0.0 valid_loss=0.009726920165121555 valid_accu=0.0
# n=64 k=0 epoch=173 train_loss=0.00970317837782204 train_accu=0.0 valid_loss=0.00971880704164505 valid_accu=0.0
# n=64 k=0 epoch=174 train_loss=0.009738591049487393 train_accu=0.0 valid_loss=0.009753004368394613 valid_accu=0.0
# n=64 k=0 epoch=175 train_loss=0.009841398180772861 train_accu=0.0 valid_loss=0.009855091944336892 valid_accu=0.0
# n=64 k=0 epoch=176 train_loss=0.009660443492854635 train_accu=0.0 valid_loss=0.009675101283937693 valid_accu=0.0
# n=64 k=0 epoch=177 train_loss=0.009781874716281891 train_accu=0.0 valid_loss=0.009796434920281172 valid_accu=0.0
# n=64 k=0 epoch=178 train_loss=0.009694306940461198 train_accu=0.0 valid_loss=0.009708567522466183 valid_accu=0.0
# n=64 k=0 epoch=179 train_loss=0.009706161109109719 train_accu=0.0 valid_loss=0.009721747972071171 valid_accu=0.0
# n=64 k=0 epoch=180 train_loss=0.009720293230687578 train_accu=0.0 valid_loss=0.00973761435598135 valid_accu=0.0
# n=64 k=0 epoch=181 train_loss=0.009705335895220438 train_accu=0.0 valid_loss=0.009720328450202941 valid_accu=0.0
# n=64 k=0 epoch=182 train_loss=0.009718321589753031 train_accu=0.0 valid_loss=0.00973101807758212 valid_accu=0.0
# n=64 k=0 epoch=183 train_loss=0.00969284529176851 train_accu=0.0 valid_loss=0.009706876520067454 valid_accu=0.0
# n=64 k=0 epoch=184 train_loss=0.009693269881730278 train_accu=0.0 valid_loss=0.009706361219286919 valid_accu=0.0
# n=64 k=0 epoch=185 train_loss=0.009690748248249292 train_accu=0.0 valid_loss=0.009705486241728067 valid_accu=0.0
# n=64 k=0 epoch=186 train_loss=0.009714545061190924 train_accu=0.0 valid_loss=0.009728614892810582 valid_accu=0.0
# n=64 k=0 epoch=187 train_loss=0.009880273106197516 train_accu=0.0 valid_loss=0.009895488992333413 valid_accu=0.0
# n=64 k=0 epoch=188 train_loss=0.009722171956673265 train_accu=0.0 valid_loss=0.009735405817627907 valid_accu=0.0
# n=64 k=0 epoch=189 train_loss=0.009778831029931705 train_accu=0.0 valid_loss=0.009791875816881656 valid_accu=0.0
# n=64 k=0 epoch=190 train_loss=0.009714154029885928 train_accu=0.0 valid_loss=0.00972891291603446 valid_accu=0.0
# n=64 k=0 epoch=191 train_loss=0.00986818023957312 train_accu=0.0 valid_loss=0.00988248735666275 valid_accu=0.0
# n=64 k=0 epoch=192 train_loss=0.00969959714760383 train_accu=0.0 valid_loss=0.009713811986148357 valid_accu=0.0
# n=64 k=0 epoch=193 train_loss=0.009829308030505975 train_accu=0.0 valid_loss=0.00984300822019577 valid_accu=0.0
# n=64 k=0 epoch=194 train_loss=0.009653012252723176 train_accu=0.0 valid_loss=0.009667079523205757 valid_accu=0.0
# n=64 k=0 epoch=195 train_loss=0.009691110750039419 train_accu=0.0 valid_loss=0.009705785382539033 valid_accu=0.0
# n=64 k=0 epoch=196 train_loss=0.00974669309022526 train_accu=0.0 valid_loss=0.009761219937354326 valid_accu=0.0
# n=64 k=0 epoch=197 train_loss=0.009683592633033792 train_accu=0.0 valid_loss=0.009696523100137711 valid_accu=0.0
# n=64 k=0 epoch=198 train_loss=0.009811870008707046 train_accu=0.0 valid_loss=0.00982675040140748 valid_accu=0.0
# n=64 k=0 epoch=199 train_loss=0.009724944767852624 train_accu=0.0 valid_loss=0.009739188943058252 valid_accu=0.0
# n=128 k=0 epoch=0 train_loss=0.019047672549883526 train_accu=0.0 valid_loss=0.01896934788674116 valid_accu=0.0
# n=128 k=0 epoch=1 train_loss=0.014164786102871101 train_accu=0.0 valid_loss=0.014120085164904594 valid_accu=0.0
# n=128 k=0 epoch=2 train_loss=0.012401428554827969 train_accu=0.0 valid_loss=0.012380259949713946 valid_accu=0.0
# n=128 k=0 epoch=3 train_loss=0.011586600076407194 train_accu=0.0 valid_loss=0.011583998519927263 valid_accu=0.0
# n=128 k=0 epoch=4 train_loss=0.010602205153554678 train_accu=0.0 valid_loss=0.010609571728855372 valid_accu=0.0
# n=128 k=0 epoch=5 train_loss=0.010087435009578864 train_accu=0.0 valid_loss=0.010095847211778164 valid_accu=0.0
# n=128 k=0 epoch=6 train_loss=0.009570409776642919 train_accu=0.0 valid_loss=0.009576820582151414 valid_accu=0.0
# n=128 k=0 epoch=7 train_loss=0.009283013067518671 train_accu=0.0 valid_loss=0.009290368761867285 valid_accu=0.0
# n=128 k=0 epoch=8 train_loss=0.009021847881376744 train_accu=0.0 valid_loss=0.009030177351087331 valid_accu=0.0
# n=128 k=0 epoch=9 train_loss=0.008782938153793414 train_accu=0.0 valid_loss=0.00879057301208377 valid_accu=0.0
# n=128 k=0 epoch=10 train_loss=0.008626017735029261 train_accu=0.0 valid_loss=0.008636488020420075 valid_accu=0.0
# n=128 k=0 epoch=11 train_loss=0.008625601433838408 train_accu=0.0 valid_loss=0.008637441042810678 valid_accu=0.0
# n=128 k=0 epoch=12 train_loss=0.008496501514067252 train_accu=0.0 valid_loss=0.00850873813033104 valid_accu=0.0
# n=128 k=0 epoch=13 train_loss=0.00819522172678262 train_accu=0.0 valid_loss=0.008208134677261114 valid_accu=0.0
# n=128 k=0 epoch=14 train_loss=0.008100563598175844 train_accu=0.0 valid_loss=0.0081137889996171 valid_accu=0.0
# n=128 k=0 epoch=15 train_loss=0.008021058569041391 train_accu=0.0 valid_loss=0.008035566238686443 valid_accu=0.0
# n=128 k=0 epoch=16 train_loss=0.008070028487903376 train_accu=0.0 valid_loss=0.008085587248206138 valid_accu=0.0
# n=128 k=0 epoch=17 train_loss=0.007872763330427308 train_accu=0.0 valid_loss=0.007889190781861543 valid_accu=0.0
# n=128 k=0 epoch=18 train_loss=0.008112133550457656 train_accu=0.0 valid_loss=0.00813276469707489 valid_accu=0.0
# n=128 k=0 epoch=19 train_loss=0.007895108545199037 train_accu=0.0 valid_loss=0.007913874369114638 valid_accu=0.0
# n=128 k=0 epoch=20 train_loss=0.0078060317629327376 train_accu=0.0 valid_loss=0.007825450180098415 valid_accu=0.0
# n=128 k=0 epoch=21 train_loss=0.00772541092398266 train_accu=0.0 valid_loss=0.007745439326390624 valid_accu=0.0
# n=128 k=0 epoch=22 train_loss=0.007619953209844728 train_accu=0.0 valid_loss=0.00764004779048264 valid_accu=0.0
# n=128 k=0 epoch=23 train_loss=0.007686661610690256 train_accu=0.0 valid_loss=0.007707531144842505 valid_accu=0.0
# n=128 k=0 epoch=24 train_loss=0.0075038933350394165 train_accu=0.0 valid_loss=0.007525083282962442 valid_accu=0.0
# n=128 k=0 epoch=25 train_loss=0.0074952594237402085 train_accu=0.0 valid_loss=0.0075170144904404875 valid_accu=0.0
# n=128 k=0 epoch=26 train_loss=0.007488032500259578 train_accu=0.0 valid_loss=0.007510904595255852 valid_accu=0.0
# n=128 k=0 epoch=27 train_loss=0.007445565075613558 train_accu=0.0 valid_loss=0.007468385947868228 valid_accu=0.0
# n=128 k=0 epoch=28 train_loss=0.0074357035492236415 train_accu=0.0 valid_loss=0.0074590933974832295 valid_accu=0.0
# n=128 k=0 epoch=29 train_loss=0.007381561592531701 train_accu=0.0 valid_loss=0.007404321245849133 valid_accu=0.0
# n=128 k=0 epoch=30 train_loss=0.007421061450925966 train_accu=0.0 valid_loss=0.00744407344609499 valid_accu=0.0
# n=128 k=0 epoch=31 train_loss=0.007354975266692539 train_accu=0.0 valid_loss=0.007378102466464043 valid_accu=0.0
# n=128 k=0 epoch=32 train_loss=0.00738184069438527 train_accu=0.0 valid_loss=0.007407162012532354 valid_accu=0.0
# n=128 k=0 epoch=33 train_loss=0.007402106056300302 train_accu=0.0 valid_loss=0.007426708843559027 valid_accu=0.0
# n=128 k=0 epoch=34 train_loss=0.0073132944215709966 train_accu=0.0 valid_loss=0.007338734855875373 valid_accu=0.0
# n=128 k=0 epoch=35 train_loss=0.007307975871178011 train_accu=0.0 valid_loss=0.007332320138812065 valid_accu=0.0
# n=128 k=0 epoch=36 train_loss=0.00730487396940589 train_accu=0.0 valid_loss=0.007330180332064629 valid_accu=0.0
# n=128 k=0 epoch=37 train_loss=0.007428640600604316 train_accu=0.0 valid_loss=0.007455212064087391 valid_accu=0.0
# n=128 k=0 epoch=38 train_loss=0.007348594985281428 train_accu=0.0 valid_loss=0.007375827291980386 valid_accu=0.0
# n=128 k=0 epoch=39 train_loss=0.007227879118484755 train_accu=0.0 valid_loss=0.00725336242467165 valid_accu=0.0
# n=128 k=0 epoch=40 train_loss=0.007226219377480447 train_accu=0.0 valid_loss=0.007251015957444906 valid_accu=0.0
# n=128 k=0 epoch=41 train_loss=0.007305249843435983 train_accu=0.0 valid_loss=0.007331346673890948 valid_accu=0.0
# n=128 k=0 epoch=42 train_loss=0.007251149485819041 train_accu=0.0 valid_loss=0.00727927042171359 valid_accu=0.0
# n=128 k=0 epoch=43 train_loss=0.007262158067896962 train_accu=0.0 valid_loss=0.007291016913950443 valid_accu=0.0
# n=128 k=0 epoch=44 train_loss=0.007218965593104561 train_accu=0.0 valid_loss=0.007246762327849865 valid_accu=0.0
# n=128 k=0 epoch=45 train_loss=0.007169518262768785 train_accu=0.0 valid_loss=0.00719713787548244 valid_accu=0.0
# n=128 k=0 epoch=46 train_loss=0.007210679911077022 train_accu=0.0 valid_loss=0.007239023549482226 valid_accu=0.0
# n=128 k=0 epoch=47 train_loss=0.007258962172393997 train_accu=0.0 valid_loss=0.007287972280755639 valid_accu=0.0
# n=128 k=0 epoch=48 train_loss=0.007179750494348506 train_accu=0.0 valid_loss=0.007209259504452348 valid_accu=0.0
# n=128 k=0 epoch=49 train_loss=0.007321262413946291 train_accu=0.0 valid_loss=0.0073523107450455425 valid_accu=0.0
# n=128 k=0 epoch=50 train_loss=0.007174131491531928 train_accu=0.0 valid_loss=0.007202544715255499 valid_accu=0.0
# n=128 k=0 epoch=51 train_loss=0.007218122171858947 train_accu=0.0 valid_loss=0.007247344218194484 valid_accu=0.0
# n=128 k=0 epoch=52 train_loss=0.007128641048135857 train_accu=0.0 valid_loss=0.0071584686636924745 valid_accu=0.0
# n=128 k=0 epoch=53 train_loss=0.00712731439465036 train_accu=0.0 valid_loss=0.007156601641327143 valid_accu=0.0
# n=128 k=0 epoch=54 train_loss=0.007186122122220695 train_accu=0.0 valid_loss=0.007216951623558998 valid_accu=0.0
# n=128 k=0 epoch=55 train_loss=0.007235345842006306 train_accu=0.0 valid_loss=0.007266836753115058 valid_accu=0.0
# n=128 k=0 epoch=56 train_loss=0.007111617410555482 train_accu=0.0 valid_loss=0.007141774101182818 valid_accu=0.0
# n=128 k=0 epoch=57 train_loss=0.007152849420284231 train_accu=0.0 valid_loss=0.007184668257832527 valid_accu=0.0
# n=128 k=0 epoch=58 train_loss=0.00706330519169569 train_accu=0.0 valid_loss=0.00709421718493104 valid_accu=0.0
# n=128 k=0 epoch=59 train_loss=0.007137746914910773 train_accu=0.0 valid_loss=0.007168625295162201 valid_accu=0.0
# n=128 k=0 epoch=60 train_loss=0.007112566288560629 train_accu=0.0 valid_loss=0.007142190076410771 valid_accu=0.0
# n=128 k=0 epoch=61 train_loss=0.0071052042301744224 train_accu=0.0 valid_loss=0.007136537833139301 valid_accu=0.0
# n=128 k=0 epoch=62 train_loss=0.007188544057620068 train_accu=0.0 valid_loss=0.007220442360267043 valid_accu=0.0
# n=128 k=0 epoch=63 train_loss=0.007035402006780108 train_accu=0.0 valid_loss=0.007066852739080786 valid_accu=0.0
# n=128 k=0 epoch=64 train_loss=0.0070381029120956855 train_accu=0.0 valid_loss=0.0070698302239179615 valid_accu=0.0
# n=128 k=0 epoch=65 train_loss=0.0071188324907173715 train_accu=0.0 valid_loss=0.007152144843712449 valid_accu=0.0
# n=128 k=0 epoch=66 train_loss=0.007051188009791076 train_accu=0.0 valid_loss=0.007081975322216749 valid_accu=0.0
# n=128 k=0 epoch=67 train_loss=0.007009462701777617 train_accu=0.0 valid_loss=0.007040147250518203 valid_accu=0.0
# n=128 k=0 epoch=68 train_loss=0.007113555958494544 train_accu=0.0 valid_loss=0.007145872572436929 valid_accu=0.0
# n=128 k=0 epoch=69 train_loss=0.007003157570337256 train_accu=0.0 valid_loss=0.007033673534169793 valid_accu=0.0
# n=128 k=0 epoch=70 train_loss=0.007027652254328132 train_accu=0.0 valid_loss=0.007058872003108263 valid_accu=0.0
# n=128 k=0 epoch=71 train_loss=0.007010638574138283 train_accu=0.0 valid_loss=0.007042665686458349 valid_accu=0.0
# n=128 k=0 epoch=72 train_loss=0.006988914893008768 train_accu=0.0 valid_loss=0.007020400650799274 valid_accu=0.0
# n=128 k=0 epoch=73 train_loss=0.007030560697118441 train_accu=0.0 valid_loss=0.007062522741034627 valid_accu=0.0
# n=128 k=0 epoch=74 train_loss=0.006964089558459818 train_accu=0.0 valid_loss=0.0069954777136445045 valid_accu=0.0
# n=128 k=0 epoch=75 train_loss=0.007025141602692505 train_accu=0.0 valid_loss=0.007055831141769886 valid_accu=0.0
# n=128 k=0 epoch=76 train_loss=0.006994457504091164 train_accu=0.0 valid_loss=0.007027389435097575 valid_accu=0.0
# n=128 k=0 epoch=77 train_loss=0.007188113608087103 train_accu=0.0 valid_loss=0.007221105881035328 valid_accu=0.0
# n=128 k=0 epoch=78 train_loss=0.006957159129281839 train_accu=0.0 valid_loss=0.006988545134663582 valid_accu=0.0
# n=128 k=0 epoch=79 train_loss=0.006956986438793441 train_accu=0.0 valid_loss=0.006987388897687197 valid_accu=0.0
# n=128 k=0 epoch=80 train_loss=0.006921400859331091 train_accu=0.0 valid_loss=0.006951325433328747 valid_accu=0.0
# n=128 k=0 epoch=81 train_loss=0.006958087362969915 train_accu=0.0 valid_loss=0.006989996274933219 valid_accu=0.0
# n=128 k=0 epoch=82 train_loss=0.006901776449133952 train_accu=0.0 valid_loss=0.006933584762737155 valid_accu=0.0
# n=128 k=0 epoch=83 train_loss=0.007087131193839013 train_accu=0.0 valid_loss=0.007121233642101288 valid_accu=0.0
# n=128 k=0 epoch=84 train_loss=0.0069031640111158294 train_accu=0.0 valid_loss=0.0069364218041300775 valid_accu=0.0
# n=128 k=0 epoch=85 train_loss=0.006916756772746642 train_accu=0.0 valid_loss=0.006947702215984464 valid_accu=0.0
# n=128 k=0 epoch=86 train_loss=0.007001156872138381 train_accu=0.0 valid_loss=0.0070335616823285815 valid_accu=0.0
# n=128 k=0 epoch=87 train_loss=0.006896877847611904 train_accu=0.0 valid_loss=0.0069291661493480206 valid_accu=0.0
# n=128 k=0 epoch=88 train_loss=0.006919909485926231 train_accu=0.0 valid_loss=0.0069533707574009895 valid_accu=0.0
# n=128 k=0 epoch=89 train_loss=0.006884466328968605 train_accu=0.0 valid_loss=0.006917412718757987 valid_accu=0.0
# n=128 k=0 epoch=90 train_loss=0.006907043179186682 train_accu=0.0 valid_loss=0.00694264960475266 valid_accu=0.0
# n=128 k=0 epoch=91 train_loss=0.0068634525019054616 train_accu=0.0 valid_loss=0.006897775596007705 valid_accu=0.0
# n=128 k=0 epoch=92 train_loss=0.0070175752509385346 train_accu=0.0 valid_loss=0.00705129886046052 valid_accu=0.0
# n=128 k=0 epoch=93 train_loss=0.006882821093313396 train_accu=0.0 valid_loss=0.00691730035468936 valid_accu=0.0
# n=128 k=0 epoch=94 train_loss=0.006873654938923816 train_accu=0.0 valid_loss=0.006907093804329634 valid_accu=0.0
# n=128 k=0 epoch=95 train_loss=0.007041356534076234 train_accu=0.0 valid_loss=0.007076170668005944 valid_accu=0.0
# n=128 k=0 epoch=96 train_loss=0.006844666902907193 train_accu=0.0 valid_loss=0.006878626020625234 valid_accu=0.0
# n=128 k=0 epoch=97 train_loss=0.006870953009153405 train_accu=0.0 valid_loss=0.006906838761642576 valid_accu=0.0
# n=128 k=0 epoch=98 train_loss=0.007012035511434078 train_accu=0.0 valid_loss=0.007047078385949135 valid_accu=0.0
# n=128 k=0 epoch=99 train_loss=0.006913477958490451 train_accu=0.0 valid_loss=0.006950305262580514 valid_accu=0.0
# n=128 k=0 epoch=100 train_loss=0.007063776557333768 train_accu=0.0 valid_loss=0.007099320227280259 valid_accu=0.0
# n=128 k=0 epoch=101 train_loss=0.006865226516189675 train_accu=0.0 valid_loss=0.006899153534322977 valid_accu=0.0
# n=128 k=0 epoch=102 train_loss=0.006848690705373884 train_accu=0.0 valid_loss=0.0068833345081657175 valid_accu=0.0
# n=128 k=0 epoch=103 train_loss=0.006920583080500364 train_accu=0.0 valid_loss=0.0069560769479721785 valid_accu=0.0
# n=128 k=0 epoch=104 train_loss=0.006816712689275543 train_accu=0.0 valid_loss=0.006851390097290277 valid_accu=0.0
# n=128 k=0 epoch=105 train_loss=0.006872466253116727 train_accu=0.0 valid_loss=0.006907557789236307 valid_accu=0.0
# n=128 k=0 epoch=106 train_loss=0.007012545115624865 train_accu=0.0 valid_loss=0.007048593275249005 valid_accu=0.0
# n=128 k=0 epoch=107 train_loss=0.007074543399115404 train_accu=0.0 valid_loss=0.007111090933904052 valid_accu=0.0
# n=128 k=0 epoch=108 train_loss=0.006848353457947572 train_accu=0.0 valid_loss=0.006885430729016662 valid_accu=0.0
# n=128 k=0 epoch=109 train_loss=0.00679820089135319 train_accu=0.0 valid_loss=0.006833467213436961 valid_accu=0.0
# n=128 k=0 epoch=110 train_loss=0.006903964242277046 train_accu=0.0 valid_loss=0.006939175259321928 valid_accu=0.0
# n=128 k=0 epoch=111 train_loss=0.006858669330055515 train_accu=0.0 valid_loss=0.006895004445686937 valid_accu=0.0
# n=128 k=0 epoch=112 train_loss=0.007034010913533469 train_accu=0.0 valid_loss=0.00707007241435349 valid_accu=0.0
# n=128 k=0 epoch=113 train_loss=0.006778504575292269 train_accu=0.0 valid_loss=0.006812908360734582 valid_accu=0.0
# n=128 k=0 epoch=114 train_loss=0.006886244844645261 train_accu=0.0 valid_loss=0.006921649910509586 valid_accu=0.0
# n=128 k=0 epoch=115 train_loss=0.006821532213749985 train_accu=0.0 valid_loss=0.006856937427073717 valid_accu=0.0
# n=128 k=0 epoch=116 train_loss=0.0067678890811900295 train_accu=0.0 valid_loss=0.006802447605878115 valid_accu=0.0
# n=128 k=0 epoch=117 train_loss=0.006793828355148435 train_accu=0.0 valid_loss=0.006829657033085823 valid_accu=0.0
# n=128 k=0 epoch=118 train_loss=0.006726937360751132 train_accu=0.0 valid_loss=0.0067629225086420774 valid_accu=0.0
# n=128 k=0 epoch=119 train_loss=0.0068139573559165 train_accu=0.0 valid_loss=0.006848404137417674 valid_accu=0.0
# n=128 k=0 epoch=120 train_loss=0.006810022401623428 train_accu=0.0 valid_loss=0.006846629455685616 valid_accu=0.0
# n=128 k=0 epoch=121 train_loss=0.006764744586932162 train_accu=0.0 valid_loss=0.006801693374291063 valid_accu=0.0
# n=128 k=0 epoch=122 train_loss=0.006797015698005756 train_accu=0.0 valid_loss=0.0068316680379211904 valid_accu=0.0
# n=128 k=0 epoch=123 train_loss=0.0067698443153252205 train_accu=0.0 valid_loss=0.006804986298084259 valid_accu=0.0
# n=128 k=0 epoch=124 train_loss=0.00679891265463084 train_accu=0.0 valid_loss=0.0068344265222549435 valid_accu=0.0
# n=128 k=0 epoch=125 train_loss=0.006787428166717291 train_accu=0.0 valid_loss=0.0068221548572182655 valid_accu=0.0
# n=128 k=0 epoch=126 train_loss=0.0067322570985804 train_accu=0.0 valid_loss=0.006767240958288312 valid_accu=0.0
# n=128 k=0 epoch=127 train_loss=0.006761027569882572 train_accu=0.0 valid_loss=0.006796784931793809 valid_accu=0.0
# n=128 k=0 epoch=128 train_loss=0.006801891668389241 train_accu=0.0 valid_loss=0.006838291557505727 valid_accu=0.0
# n=128 k=0 epoch=129 train_loss=0.0067786442503953975 train_accu=0.0 valid_loss=0.00681287283077836 valid_accu=0.0
# n=128 k=0 epoch=130 train_loss=0.006698533535624543 train_accu=0.0 valid_loss=0.006733298534527421 valid_accu=0.0
# n=128 k=0 epoch=131 train_loss=0.006799671915359795 train_accu=0.0 valid_loss=0.006834859913215041 valid_accu=0.0
# n=128 k=0 epoch=132 train_loss=0.0067696043600638705 train_accu=0.0 valid_loss=0.006804254045709968 valid_accu=0.0
# n=128 k=0 epoch=133 train_loss=0.006715715164318681 train_accu=0.0 valid_loss=0.006751277018338442 valid_accu=0.0
# n=128 k=0 epoch=134 train_loss=0.00676167084214588 train_accu=0.0 valid_loss=0.006795685226097703 valid_accu=0.0
# n=128 k=0 epoch=135 train_loss=0.006774679532585045 train_accu=0.0 valid_loss=0.006809459766373038 valid_accu=0.0
# n=128 k=0 epoch=136 train_loss=0.006763730073968569 train_accu=0.0 valid_loss=0.00679744235239923 valid_accu=0.0
# n=128 k=0 epoch=137 train_loss=0.006693569609584908 train_accu=0.0 valid_loss=0.006728733610361815 valid_accu=0.0
# n=128 k=0 epoch=138 train_loss=0.006674035592004657 train_accu=0.0 valid_loss=0.006707721669226885 valid_accu=0.0
# n=128 k=0 epoch=139 train_loss=0.006733131106011569 train_accu=0.0 valid_loss=0.006768806790933013 valid_accu=0.0
# n=128 k=0 epoch=140 train_loss=0.006692707639498015 train_accu=0.0 valid_loss=0.006727213785052299 valid_accu=0.0
# n=128 k=0 epoch=141 train_loss=0.00674815825962772 train_accu=0.0 valid_loss=0.006781762884929776 valid_accu=0.0
# n=128 k=0 epoch=142 train_loss=0.006731603240283827 train_accu=0.0 valid_loss=0.0067664430476725105 valid_accu=0.0
# n=128 k=0 epoch=143 train_loss=0.0067512475807840625 train_accu=0.0 valid_loss=0.006786267412826419 valid_accu=0.0
# n=128 k=0 epoch=144 train_loss=0.006687409919686615 train_accu=0.0 valid_loss=0.006722418637946248 valid_accu=0.0
# n=128 k=0 epoch=145 train_loss=0.006662635854445398 train_accu=0.0 valid_loss=0.0066975773312151436 valid_accu=0.0
# n=128 k=0 epoch=146 train_loss=0.006687308902231356 train_accu=0.0 valid_loss=0.006721846386790275 valid_accu=0.0
# n=128 k=0 epoch=147 train_loss=0.006650572859992584 train_accu=0.0 valid_loss=0.006685790978372097 valid_accu=0.0
# n=128 k=0 epoch=148 train_loss=0.006678062584251165 train_accu=0.0 valid_loss=0.006714055361226201 valid_accu=0.0
# n=128 k=0 epoch=149 train_loss=0.006696662136043112 train_accu=0.0 valid_loss=0.006731749512255192 valid_accu=0.0
# n=128 k=0 epoch=150 train_loss=0.006692280814362069 train_accu=0.0 valid_loss=0.006728567043319344 valid_accu=0.0
# n=128 k=0 epoch=151 train_loss=0.006774800705413023 train_accu=0.0 valid_loss=0.006809637928381562 valid_accu=0.0
# n=128 k=0 epoch=152 train_loss=0.006702915734301011 train_accu=0.0 valid_loss=0.006736308801919222 valid_accu=0.0
# n=128 k=0 epoch=153 train_loss=0.006684641144238413 train_accu=0.0 valid_loss=0.006719245854765177 valid_accu=0.0
# n=128 k=0 epoch=154 train_loss=0.0066832151962444184 train_accu=0.0 valid_loss=0.006718431040644646 valid_accu=0.0
# n=128 k=0 epoch=155 train_loss=0.006647229877611001 train_accu=0.0 valid_loss=0.0066821344662457705 valid_accu=0.0
# n=128 k=0 epoch=156 train_loss=0.0067091482691466805 train_accu=0.0 valid_loss=0.006745231850072741 valid_accu=0.0
# n=128 k=0 epoch=157 train_loss=0.0066604154262070855 train_accu=0.0 valid_loss=0.006696047307923436 valid_accu=0.0
# n=128 k=0 epoch=158 train_loss=0.006737113767303527 train_accu=0.0 valid_loss=0.00677262363024056 valid_accu=0.0
# n=128 k=0 epoch=159 train_loss=0.006713262153789401 train_accu=0.0 valid_loss=0.0067485345993191 valid_accu=0.0
# n=128 k=0 epoch=160 train_loss=0.0067570063984021544 train_accu=0.0 valid_loss=0.006792812934145331 valid_accu=0.0
# n=128 k=0 epoch=161 train_loss=0.0066863838272790115 train_accu=0.0 valid_loss=0.006722615100443363 valid_accu=0.0
# n=128 k=0 epoch=162 train_loss=0.006722023066443702 train_accu=0.0 valid_loss=0.006756478268653154 valid_accu=0.0
# n=128 k=0 epoch=163 train_loss=0.00663124182416747 train_accu=0.0 valid_loss=0.0066664715763181445 valid_accu=0.0
# n=128 k=0 epoch=164 train_loss=0.006639968029533824 train_accu=0.0 valid_loss=0.006675100419670343 valid_accu=0.0
# n=128 k=0 epoch=165 train_loss=0.006791852212821444 train_accu=0.0 valid_loss=0.006827692734077573 valid_accu=0.0
# n=128 k=0 epoch=166 train_loss=0.006722039791444937 train_accu=0.0 valid_loss=0.006757252849638462 valid_accu=0.0
# n=128 k=0 epoch=167 train_loss=0.006687135885780056 train_accu=0.0 valid_loss=0.0067228296305984255 valid_accu=0.0
# n=128 k=0 epoch=168 train_loss=0.006709704625730713 train_accu=0.0 valid_loss=0.006743300752714276 valid_accu=0.0
# n=128 k=0 epoch=169 train_loss=0.006763470366907617 train_accu=0.0 valid_loss=0.006799105228856206 valid_accu=0.0
# n=128 k=0 epoch=170 train_loss=0.006688342406414449 train_accu=0.0 valid_loss=0.006721737049520016 valid_accu=0.0
# n=128 k=0 epoch=171 train_loss=0.006775635108351707 train_accu=0.0 valid_loss=0.006809339486062526 valid_accu=0.0
# n=128 k=0 epoch=172 train_loss=0.0066720227710902694 train_accu=0.0 valid_loss=0.006705622095614672 valid_accu=0.0
# n=128 k=0 epoch=173 train_loss=0.00664490907608221 train_accu=0.0 valid_loss=0.006680032331496477 valid_accu=0.0
# n=128 k=0 epoch=174 train_loss=0.006711342597069839 train_accu=0.0 valid_loss=0.006746803829446435 valid_accu=0.0
# n=128 k=0 epoch=175 train_loss=0.006803937202009062 train_accu=0.0 valid_loss=0.006839389773085713 valid_accu=0.0
# n=128 k=0 epoch=176 train_loss=0.006678694781536858 train_accu=0.0 valid_loss=0.006713874638080597 valid_accu=0.0
# n=128 k=0 epoch=177 train_loss=0.006709627908033629 train_accu=0.0 valid_loss=0.006744140898808837 valid_accu=0.0
# n=128 k=0 epoch=178 train_loss=0.006702293013222516 train_accu=0.0 valid_loss=0.006736233411356807 valid_accu=0.0
# n=128 k=0 epoch=179 train_loss=0.006785046914592386 train_accu=0.0 valid_loss=0.006819076091051102 valid_accu=0.0
# n=128 k=0 epoch=180 train_loss=0.006735474041973551 train_accu=0.0 valid_loss=0.006771422550082206 valid_accu=0.0
# n=128 k=0 epoch=181 train_loss=0.006701764239308735 train_accu=0.0 valid_loss=0.006738437945023179 valid_accu=0.0
# n=128 k=0 epoch=182 train_loss=0.006666657188907266 train_accu=0.0 valid_loss=0.006703262683004141 valid_accu=0.0
# n=128 k=0 epoch=183 train_loss=0.0066341527660066886 train_accu=0.0 valid_loss=0.006668304279446602 valid_accu=0.0
# n=128 k=0 epoch=184 train_loss=0.006599784153513611 train_accu=0.0 valid_loss=0.006635686988011003 valid_accu=0.0
# n=128 k=0 epoch=185 train_loss=0.006689214085539182 train_accu=0.0 valid_loss=0.006724706571549177 valid_accu=0.0
# n=128 k=0 epoch=186 train_loss=0.006707692922403415 train_accu=0.0 valid_loss=0.006742708384990692 valid_accu=0.0
# n=128 k=0 epoch=187 train_loss=0.006702524734040102 train_accu=0.0 valid_loss=0.006738221272826195 valid_accu=0.0
# n=128 k=0 epoch=188 train_loss=0.006669803522527218 train_accu=0.0 valid_loss=0.0067064807750284675 valid_accu=0.0
# n=128 k=0 epoch=189 train_loss=0.006697507140537103 train_accu=0.0 valid_loss=0.006732141925022006 valid_accu=0.0
# n=128 k=0 epoch=190 train_loss=0.006675705274877449 train_accu=0.0 valid_loss=0.006711513502523303 valid_accu=0.0
# n=128 k=0 epoch=191 train_loss=0.00669694747775793 train_accu=0.0 valid_loss=0.00673127374611795 valid_accu=0.0
# n=128 k=0 epoch=192 train_loss=0.006647312392791112 train_accu=0.0 valid_loss=0.00668337126262486 valid_accu=0.0
# n=128 k=0 epoch=193 train_loss=0.00673448690213263 train_accu=0.0 valid_loss=0.006769289774820208 valid_accu=0.0
# n=128 k=0 epoch=194 train_loss=0.0066657853235180175 train_accu=0.0 valid_loss=0.00670254286378622 valid_accu=0.0
# n=128 k=0 epoch=195 train_loss=0.006680726756652196 train_accu=0.0 valid_loss=0.006715334625914693 valid_accu=0.0
# n=128 k=0 epoch=196 train_loss=0.006657531578093767 train_accu=0.0 valid_loss=0.0066919912118464705 valid_accu=0.0
# n=128 k=0 epoch=197 train_loss=0.006630121062820156 train_accu=0.0 valid_loss=0.006666317256167531 valid_accu=0.0
# n=128 k=0 epoch=198 train_loss=0.006644299649633467 train_accu=0.0 valid_loss=0.006680160108953714 valid_accu=0.0
# n=128 k=0 epoch=199 train_loss=0.006659342690060536 train_accu=0.0 valid_loss=0.00669508446007967 valid_accu=0.0
# n=256 k=0 epoch=0 train_loss=0.014198106061667205 train_accu=0.0 valid_loss=0.01415911503136158 valid_accu=0.0
# n=256 k=0 epoch=1 train_loss=0.010862207800770799 train_accu=0.0 valid_loss=0.010865581966936589 valid_accu=0.0
# n=256 k=0 epoch=2 train_loss=0.009824843270083268 train_accu=0.0 valid_loss=0.009840320143848658 valid_accu=0.0
# n=256 k=0 epoch=3 train_loss=0.008675219723954797 train_accu=0.0 valid_loss=0.00869061267003417 valid_accu=0.0
# n=256 k=0 epoch=4 train_loss=0.008242092157403628 train_accu=0.0 valid_loss=0.008261626679450273 valid_accu=0.0
# n=256 k=0 epoch=5 train_loss=0.007665124884806573 train_accu=0.0 valid_loss=0.007682113768532872 valid_accu=0.0
# n=256 k=0 epoch=6 train_loss=0.007261376129463315 train_accu=0.0 valid_loss=0.007280379394069314 valid_accu=0.0
# n=256 k=0 epoch=7 train_loss=0.007062470548165342 train_accu=0.0 valid_loss=0.007084752200171351 valid_accu=0.0
# n=256 k=0 epoch=8 train_loss=0.006798296375200153 train_accu=0.0 valid_loss=0.006821031775325536 valid_accu=0.0
# n=256 k=0 epoch=9 train_loss=0.00671906650532037 train_accu=0.0 valid_loss=0.006744223507121205 valid_accu=0.0
# n=256 k=0 epoch=10 train_loss=0.0066597592473650975 train_accu=0.0 valid_loss=0.006686389539390802 valid_accu=0.0
# n=256 k=0 epoch=11 train_loss=0.0064501304257040225 train_accu=0.0 valid_loss=0.006481266953051091 valid_accu=0.0
# n=256 k=0 epoch=12 train_loss=0.006370429322123528 train_accu=0.0 valid_loss=0.006399750150740147 valid_accu=0.0
# n=256 k=0 epoch=13 train_loss=0.006152201296451191 train_accu=0.0 valid_loss=0.006182486517354846 valid_accu=0.0
# n=256 k=0 epoch=14 train_loss=0.006102610325130323 train_accu=0.0 valid_loss=0.0061339470092207195 valid_accu=0.0
# n=256 k=0 epoch=15 train_loss=0.005969658851002654 train_accu=0.0 valid_loss=0.006001601414754987 valid_accu=0.0
# n=256 k=0 epoch=16 train_loss=0.005965950262422363 train_accu=0.0 valid_loss=0.006001085927709937 valid_accu=0.0
# n=256 k=0 epoch=17 train_loss=0.005995917359056572 train_accu=0.0 valid_loss=0.006033364869654179 valid_accu=0.0
# n=256 k=0 epoch=18 train_loss=0.005980704484197001 train_accu=0.0 valid_loss=0.006013135984539985 valid_accu=0.0
# n=256 k=0 epoch=19 train_loss=0.005762478437585135 train_accu=0.0 valid_loss=0.005800190009176731 valid_accu=0.0
# n=256 k=0 epoch=20 train_loss=0.00566793573088944 train_accu=0.0 valid_loss=0.005703758215531707 valid_accu=0.0
# n=256 k=0 epoch=21 train_loss=0.0056476967176422475 train_accu=0.0 valid_loss=0.005684097623452544 valid_accu=0.0
# n=256 k=0 epoch=22 train_loss=0.005599245211730401 train_accu=0.0 valid_loss=0.005636758217588067 valid_accu=0.0
# n=256 k=0 epoch=23 train_loss=0.005700505835314592 train_accu=0.0 valid_loss=0.005738946283236146 valid_accu=0.0
# n=256 k=0 epoch=24 train_loss=0.005516324130197366 train_accu=0.0 valid_loss=0.005554855521768332 valid_accu=0.0
# ...
# n=512 k=0 epoch=61 train_loss=0.0033654564642347394 train_accu=0.0 valid_loss=0.003435917687602341 valid_accu=0.0
# n=512 k=0 epoch=62 train_loss=0.0034357514581643046 train_accu=0.0 valid_loss=0.0035057092318311334 valid_accu=0.0
# n=512 k=0 epoch=63 train_loss=0.003507670178078115 train_accu=0.0 valid_loss=0.0035787838976830246 valid_accu=0.0
# n=512 k=0 epoch=64 train_loss=0.003316398496584346 train_accu=0.0 valid_loss=0.0033875932916998864 valid_accu=0.0
# n=512 k=0 epoch=65 train_loss=0.0033498637960292397 train_accu=0.0 valid_loss=0.003421517391689122 valid_accu=0.0
# n=512 k=0 epoch=66 train_loss=0.0033778821622642377 train_accu=0.0 valid_loss=0.0034492753678932787 valid_accu=0.0
# n=512 k=0 epoch=67 train_loss=0.0034325195359997452 train_accu=0.0 valid_loss=0.003505358216352761 valid_accu=0.0
# n=512 k=0 epoch=68 train_loss=0.003501103942592939 train_accu=0.0 valid_loss=0.0035788956563919784 valid_accu=0.0
# n=512 k=0 epoch=69 train_loss=0.0033699373559405404 train_accu=0.0 valid_loss=0.0034426160389557483 valid_accu=0.0
# n=512 k=0 epoch=70 train_loss=0.0033432629735519487 train_accu=0.0 valid_loss=0.0034173378720879556 valid_accu=0.0
# n=512 k=0 epoch=71 train_loss=0.0032816481466094653 train_accu=0.0 valid_loss=0.0033539019292220472 valid_accu=0.0
# n=512 k=0 epoch=72 train_loss=0.003285109888141354 train_accu=0.0 valid_loss=0.0033587248995900153 valid_accu=0.0
# n=512 k=0 epoch=73 train_loss=0.003379290116329988 train_accu=0.0 valid_loss=0.003452371177263558 valid_accu=0.0
# n=512 k=0 epoch=74 train_loss=0.003320641761335234 train_accu=0.0 valid_loss=0.003394198860041797 valid_accu=0.0
# n=512 k=0 epoch=75 train_loss=0.0032583743333816527 train_accu=0.0 valid_loss=0.0033320118207484485 valid_accu=0.0
# n=512 k=0 epoch=76 train_loss=0.003273714492873599 train_accu=0.0 valid_loss=0.003347024950198829 valid_accu=0.0
# n=512 k=0 epoch=77 train_loss=0.0033766016519318023 train_accu=0.0 valid_loss=0.003450170182622969 valid_accu=0.0
# n=512 k=0 epoch=78 train_loss=0.003253657002157221 train_accu=0.0 valid_loss=0.003327398281544447 valid_accu=0.0
# n=512 k=0 epoch=79 train_loss=0.0033963110724774498 train_accu=0.0 valid_loss=0.0034673187183216214 valid_accu=0.0
# n=512 k=0 epoch=80 train_loss=0.003205548145342618 train_accu=0.0 valid_loss=0.0032813157187774776 valid_accu=0.0
# n=512 k=0 epoch=81 train_loss=0.003262553740448008 train_accu=0.0 valid_loss=0.0033376557752490045 valid_accu=0.0
# n=512 k=0 epoch=82 train_loss=0.003196692393006136 train_accu=0.0 valid_loss=0.0032703156350180505 valid_accu=0.0
# n=512 k=0 epoch=83 train_loss=0.003267120678598682 train_accu=0.0 valid_loss=0.0033394563011825084 valid_accu=0.0
# n=512 k=0 epoch=84 train_loss=0.003296506971431275 train_accu=0.0 valid_loss=0.0033751707756891846 valid_accu=0.0
# n=512 k=0 epoch=85 train_loss=0.0032933302068461974 train_accu=0.0 valid_loss=0.003370968019589782 valid_accu=0.0
# n=512 k=0 epoch=86 train_loss=0.0034701986859242123 train_accu=0.0 valid_loss=0.0035447936737909914 valid_accu=0.0
# n=512 k=0 epoch=87 train_loss=0.0032689335833614073 train_accu=0.0 valid_loss=0.0033408765448257327 valid_accu=0.0
# n=512 k=0 epoch=88 train_loss=0.003200346623392155 train_accu=0.0 valid_loss=0.003274793503805995 valid_accu=0.0
# n=512 k=0 epoch=89 train_loss=0.003239238405755411 train_accu=0.0 valid_loss=0.0033122090622782706 valid_accu=0.0
# n=512 k=0 epoch=90 train_loss=0.0031764651842725775 train_accu=0.0 valid_loss=0.0032510113203898074 valid_accu=0.0
# n=512 k=0 epoch=91 train_loss=0.0032903852212863662 train_accu=0.0 valid_loss=0.0033640250097960235 valid_accu=0.0
# n=512 k=0 epoch=92 train_loss=0.003170783371509363 train_accu=0.0 valid_loss=0.0032467680517584085 valid_accu=0.0
# n=512 k=0 epoch=93 train_loss=0.0032895347336307167 train_accu=0.0 valid_loss=0.003368871589191258 valid_accu=0.0
# n=512 k=0 epoch=94 train_loss=0.003246807031488667 train_accu=0.0 valid_loss=0.0033205053070560096 valid_accu=0.0
# n=512 k=0 epoch=95 train_loss=0.0031492009797754387 train_accu=0.0 valid_loss=0.0032259735511615873 valid_accu=0.0
# n=512 k=0 epoch=96 train_loss=0.0031174539937637745 train_accu=0.0 valid_loss=0.0031935597537085412 valid_accu=0.0
# n=512 k=0 epoch=97 train_loss=0.003170595756576707 train_accu=0.0 valid_loss=0.0032449217513203623 valid_accu=0.0
# n=512 k=0 epoch=98 train_loss=0.0031303354849418004 train_accu=0.0 valid_loss=0.003204486146569252 valid_accu=0.0
# n=512 k=0 epoch=99 train_loss=0.0031050945942600566 train_accu=0.0 valid_loss=0.003181143756955862 valid_accu=0.0
# n=512 k=0 epoch=100 train_loss=0.0032157606445252897 train_accu=0.0 valid_loss=0.003291852166876197 valid_accu=0.0
# n=512 k=0 epoch=101 train_loss=0.0031245138534965614 train_accu=0.0 valid_loss=0.0032011832343414428 valid_accu=0.0
# n=512 k=0 epoch=102 train_loss=0.0031792894393826523 train_accu=0.0 valid_loss=0.0032595049357041716 valid_accu=0.0
# n=512 k=0 epoch=103 train_loss=0.0031727496379365524 train_accu=0.0 valid_loss=0.003253164445050061 valid_accu=0.0
# n=512 k=0 epoch=104 train_loss=0.0031523684854619207 train_accu=0.0 valid_loss=0.003228886309079826 valid_accu=0.0
# n=512 k=0 epoch=105 train_loss=0.003113476101619502 train_accu=0.0 valid_loss=0.0031916041392832995 valid_accu=0.0
# n=512 k=0 epoch=106 train_loss=0.003442989142301182 train_accu=0.0 valid_loss=0.003519222210161388 valid_accu=0.0
# n=512 k=0 epoch=107 train_loss=0.0032786058417210977 train_accu=0.0 valid_loss=0.0033537379931658506 valid_accu=0.0
# n=512 k=0 epoch=108 train_loss=0.0030995172642481823 train_accu=0.0 valid_loss=0.003175783692859113 valid_accu=0.0
# n=512 k=0 epoch=109 train_loss=0.0031004519395840665 train_accu=0.0 valid_loss=0.003178247902542353 valid_accu=0.0
# n=512 k=0 epoch=110 train_loss=0.0032706889207474886 train_accu=0.0 valid_loss=0.003345200605690479 valid_accu=0.0
# n=512 k=0 epoch=111 train_loss=0.00309785200515762 train_accu=0.0 valid_loss=0.0031749620335176586 valid_accu=0.0
# n=512 k=0 epoch=112 train_loss=0.0030987752562699217 train_accu=0.0 valid_loss=0.0031737481011077763 valid_accu=0.0
# n=512 k=0 epoch=113 train_loss=0.00315463738127922 train_accu=0.0 valid_loss=0.0032290223985910415 valid_accu=0.0
# n=512 k=0 epoch=114 train_loss=0.0031016615374634664 train_accu=0.0 valid_loss=0.0031797987408936023 valid_accu=0.0
# n=512 k=0 epoch=115 train_loss=0.003230089306210478 train_accu=0.0 valid_loss=0.0033057530410587786 valid_accu=0.0
# n=512 k=0 epoch=116 train_loss=0.0033160005851338306 train_accu=0.0 valid_loss=0.003390227910131216 valid_accu=0.0
# n=512 k=0 epoch=117 train_loss=0.0033017447295909125 train_accu=0.0 valid_loss=0.003377146949060261 valid_accu=0.0
# n=512 k=0 epoch=118 train_loss=0.0031037548983780046 train_accu=0.0 valid_loss=0.003179597924463451 valid_accu=0.0
# n=512 k=0 epoch=119 train_loss=0.0030513846354248623 train_accu=0.0 valid_loss=0.003128542983904481 valid_accu=0.0
# n=512 k=0 epoch=120 train_loss=0.003169907656653474 train_accu=0.0 valid_loss=0.003248220146633685 valid_accu=0.0
# n=512 k=0 epoch=121 train_loss=0.0030776531745990115 train_accu=0.0 valid_loss=0.003154709888622165 valid_accu=0.0
# n=512 k=0 epoch=122 train_loss=0.003144675062503666 train_accu=0.0 valid_loss=0.003222518623806536 valid_accu=0.0
# n=512 k=0 epoch=123 train_loss=0.003107731731142849 train_accu=0.0 valid_loss=0.003185529285110533 valid_accu=0.0
# n=512 k=0 epoch=124 train_loss=0.0031176106111767393 train_accu=0.0 valid_loss=0.0032020808896049855 valid_accu=0.0
# n=512 k=0 epoch=125 train_loss=0.0031196403394763666 train_accu=0.0 valid_loss=0.0031958956504240634 valid_accu=0.0
# n=512 k=0 epoch=126 train_loss=0.003073573395765076 train_accu=0.0 valid_loss=0.0031492926180362703 valid_accu=0.0
# n=512 k=0 epoch=127 train_loss=0.003201903154452642 train_accu=0.0 valid_loss=0.0032788770273327827 valid_accu=0.0
# n=512 k=0 epoch=128 train_loss=0.003074840464008351 train_accu=0.0 valid_loss=0.003152763401158154 valid_accu=0.0
# n=512 k=0 epoch=129 train_loss=0.0031602796477576095 train_accu=0.0 valid_loss=0.003236446948722005 valid_accu=0.0
# n=512 k=0 epoch=130 train_loss=0.0031428270779239637 train_accu=0.0 valid_loss=0.00322230423334986 valid_accu=0.0
# n=512 k=0 epoch=131 train_loss=0.003031502291560173 train_accu=0.0 valid_loss=0.003109563677571714 valid_accu=0.0
# n=512 k=0 epoch=132 train_loss=0.0030712735412331917 train_accu=0.0 valid_loss=0.003152338066138327 valid_accu=0.0
# n=512 k=0 epoch=133 train_loss=0.003161124888962756 train_accu=0.0 valid_loss=0.0032383307116106153 valid_accu=0.0
# n=512 k=0 epoch=134 train_loss=0.0030553427912915748 train_accu=0.0 valid_loss=0.00313334574457258 valid_accu=0.0
# n=512 k=0 epoch=135 train_loss=0.0031229327665641903 train_accu=0.0 valid_loss=0.0032013770192861556 valid_accu=0.0
# n=512 k=0 epoch=136 train_loss=0.0030764766076269248 train_accu=0.0 valid_loss=0.0031538928858935835 valid_accu=0.0
# n=512 k=0 epoch=137 train_loss=0.0030989853548817337 train_accu=0.0 valid_loss=0.0031777801457792522 valid_accu=0.0
# n=512 k=0 epoch=138 train_loss=0.00302551625839745 train_accu=0.0 valid_loss=0.0031088362680748104 valid_accu=0.0
# n=512 k=0 epoch=139 train_loss=0.0031032149291907746 train_accu=0.0 valid_loss=0.003181929560378194 valid_accu=0.0
# n=512 k=0 epoch=140 train_loss=0.0030423279968090355 train_accu=0.0 valid_loss=0.0031212465837597847 valid_accu=0.0
# n=512 k=0 epoch=141 train_loss=0.002991485921666026 train_accu=0.0 valid_loss=0.0030698300106450915 valid_accu=0.0
# n=512 k=0 epoch=142 train_loss=0.0029690091925052304 train_accu=0.0 valid_loss=0.003049424826167524 valid_accu=0.0
# n=512 k=0 epoch=143 train_loss=0.0030010533751919865 train_accu=0.0 valid_loss=0.0030802707886323335 valid_accu=0.0
# n=512 k=0 epoch=144 train_loss=0.0033013459915916124 train_accu=0.0 valid_loss=0.0033807466505095364 valid_accu=0.0
# n=512 k=0 epoch=145 train_loss=0.0029967072303406896 train_accu=0.0 valid_loss=0.0030747910495847464 valid_accu=0.0
# n=512 k=0 epoch=146 train_loss=0.0029396630202730496 train_accu=0.0 valid_loss=0.003018626826815307 valid_accu=0.0
# n=512 k=0 epoch=147 train_loss=0.0029933639452792704 train_accu=0.0 valid_loss=0.0030738690635189413 valid_accu=0.0
# n=512 k=0 epoch=148 train_loss=0.0029676076878483097 train_accu=0.0 valid_loss=0.0030471815727651117 valid_accu=0.0
# n=512 k=0 epoch=149 train_loss=0.003036961320322007 train_accu=0.0 valid_loss=0.003121388074941933 valid_accu=0.0
# n=512 k=0 epoch=150 train_loss=0.003002839853676657 train_accu=0.0 valid_loss=0.0030831215670332314 valid_accu=0.0
# n=512 k=0 epoch=151 train_loss=0.002972127861964206 train_accu=0.0 valid_loss=0.0030515405349433424 valid_accu=0.0
# n=512 k=0 epoch=152 train_loss=0.0029786959484529993 train_accu=0.0 valid_loss=0.0030580283142626285 valid_accu=0.0
# n=512 k=0 epoch=153 train_loss=0.002954135392792523 train_accu=0.0 valid_loss=0.0030327178072184326 valid_accu=0.0
# n=512 k=0 epoch=154 train_loss=0.002970069060878207 train_accu=0.0 valid_loss=0.0030512983910739424 valid_accu=0.0
# n=512 k=0 epoch=155 train_loss=0.0030257525582176943 train_accu=0.0 valid_loss=0.003105107950977981 valid_accu=0.0
# n=512 k=0 epoch=156 train_loss=0.0030261898219274977 train_accu=0.0 valid_loss=0.0031110408483073114 valid_accu=0.0
# n=512 k=0 epoch=157 train_loss=0.003045550532018145 train_accu=0.0 valid_loss=0.0031242216005921363 valid_accu=0.0
# n=512 k=0 epoch=158 train_loss=0.003004508966114372 train_accu=0.0 valid_loss=0.003090260736644268 valid_accu=0.0
# n=512 k=0 epoch=159 train_loss=0.0030698238328720133 train_accu=0.0 valid_loss=0.003149326331913471 valid_accu=0.0
# n=512 k=0 epoch=160 train_loss=0.002902253542561084 train_accu=0.0 valid_loss=0.002982526761479676 valid_accu=0.0
# n=512 k=0 epoch=161 train_loss=0.0031660472818960746 train_accu=0.0 valid_loss=0.003244302957318723 valid_accu=0.0
# n=512 k=0 epoch=162 train_loss=0.002901675101990501 train_accu=0.0 valid_loss=0.002980766608379781 valid_accu=0.0
# n=512 k=0 epoch=163 train_loss=0.002963166105716179 train_accu=0.0 valid_loss=0.0030466383323073387 valid_accu=0.0
# n=512 k=0 epoch=164 train_loss=0.0030686855975848933 train_accu=0.0 valid_loss=0.0031482804799452422 valid_accu=0.0
# n=512 k=0 epoch=165 train_loss=0.002960107141795258 train_accu=0.0 valid_loss=0.003039224212989211 valid_accu=0.0
# n=512 k=0 epoch=166 train_loss=0.002947867393959314 train_accu=0.0 valid_loss=0.0030265400884672998 valid_accu=0.0
# n=512 k=0 epoch=167 train_loss=0.0029373644734732806 train_accu=0.0 valid_loss=0.00301625719293952 valid_accu=0.0
# n=512 k=0 epoch=168 train_loss=0.003156536053090046 train_accu=0.0 valid_loss=0.003235389059409499 valid_accu=0.0
# n=512 k=0 epoch=169 train_loss=0.0029209234829371176 train_accu=0.0 valid_loss=0.003001830819994211 valid_accu=0.0
# n=512 k=0 epoch=170 train_loss=0.003085409267805517 train_accu=0.0 valid_loss=0.003164198528975248 valid_accu=0.0
# n=512 k=0 epoch=171 train_loss=0.002904659901590397 train_accu=0.0 valid_loss=0.0029855866450816393 valid_accu=0.0
# n=512 k=0 epoch=172 train_loss=0.0029108478299652535 train_accu=0.0 valid_loss=0.0029904521303251385 valid_accu=0.0
# n=512 k=0 epoch=173 train_loss=0.0030103161193740864 train_accu=0.0 valid_loss=0.003090016823261976 valid_accu=0.0
# n=512 k=0 epoch=174 train_loss=0.002970822248607874 train_accu=0.0 valid_loss=0.003052591532468796 valid_accu=0.0
# n=512 k=0 epoch=175 train_loss=0.0028984001837670803 train_accu=0.0 valid_loss=0.0029794801957905293 valid_accu=0.0
# n=512 k=0 epoch=176 train_loss=0.002875385088069985 train_accu=0.0 valid_loss=0.0029554747976362704 valid_accu=0.0
# n=512 k=0 epoch=177 train_loss=0.002974027880312254 train_accu=0.0 valid_loss=0.0030605003936216234 valid_accu=0.0
# n=512 k=0 epoch=178 train_loss=0.0029951194456468025 train_accu=0.0 valid_loss=0.0030777788255363704 valid_accu=0.0
# n=512 k=0 epoch=179 train_loss=0.002871139805453519 train_accu=0.0 valid_loss=0.002952746069058776 valid_accu=0.0
# n=512 k=0 epoch=180 train_loss=0.0029129241321546335 train_accu=0.0 valid_loss=0.002994510205462575 valid_accu=0.0
# n=512 k=0 epoch=181 train_loss=0.0028715741005726158 train_accu=0.0 valid_loss=0.0029535733396187426 valid_accu=0.0
# n=512 k=0 epoch=182 train_loss=0.003011443861760199 train_accu=0.0 valid_loss=0.003093143296428025 valid_accu=0.0
# n=512 k=0 epoch=183 train_loss=0.0029063488900040587 train_accu=0.0 valid_loss=0.0029879036592319608 valid_accu=0.0
# n=512 k=0 epoch=184 train_loss=0.0030437740652511517 train_accu=0.0 valid_loss=0.0031321184011176228 valid_accu=0.0
# n=512 k=0 epoch=185 train_loss=0.002867646104035278 train_accu=0.0 valid_loss=0.002948262635618448 valid_accu=0.0
# n=512 k=0 epoch=186 train_loss=0.0028682385299665233 train_accu=0.0 valid_loss=0.0029486551648005843 valid_accu=0.0
# n=512 k=0 epoch=187 train_loss=0.0029582315124571323 train_accu=0.0 valid_loss=0.0030426592100411655 valid_accu=0.0
# n=512 k=0 epoch=188 train_loss=0.002932384757635494 train_accu=0.0 valid_loss=0.0030128416838124394 valid_accu=0.0
# n=512 k=0 epoch=189 train_loss=0.0028851988802974424 train_accu=0.0 valid_loss=0.0029682132648304106 valid_accu=0.0
# n=512 k=0 epoch=190 train_loss=0.0029315103427506985 train_accu=0.0 valid_loss=0.0030157299246639014 valid_accu=0.0
# n=512 k=0 epoch=191 train_loss=0.0029320016542139153 train_accu=0.0 valid_loss=0.003012614976614714 valid_accu=0.0
# n=512 k=0 epoch=192 train_loss=0.002868783373075227 train_accu=0.0 valid_loss=0.002949839807115495 valid_accu=0.0
# n=512 k=0 epoch=193 train_loss=0.002898252580780536 train_accu=0.0 valid_loss=0.002979692490771413 valid_accu=0.0
# n=512 k=0 epoch=194 train_loss=0.0029893896852930387 train_accu=0.0 valid_loss=0.0030760637717321517 valid_accu=0.0
# n=512 k=0 epoch=195 train_loss=0.0028634697936164837 train_accu=0.0 valid_loss=0.002945947088301182 valid_accu=0.0
# n=512 k=0 epoch=196 train_loss=0.00287580150567616 train_accu=0.0 valid_loss=0.002958127739839256 valid_accu=0.0
# n=512 k=0 epoch=197 train_loss=0.003086635210396101 train_accu=0.0 valid_loss=0.0031748487148433925 valid_accu=0.0
# n=512 k=0 epoch=198 train_loss=0.0029107532153526943 train_accu=0.0 valid_loss=0.002991953631862998 valid_accu=0.0
# n=512 k=0 epoch=199 train_loss=0.002974535191121201 train_accu=0.0 valid_loss=0.0030594690470024943 valid_accu=0.0

# %%
# Elegimos una imagen y calculamos la correspondiente prediccion generada por el modelo.
sample_idx = torch.randint(len(test_dataset),size=(1,)).item()
imagen,label = test_dataset[sample_idx]
print(f"imagen.shape={imagen.shape}")
imagen_gpu = imagen.to(device)
pred_gpu = model(imagen_gpu)
pred_cpu = pred_gpu.detach().cpu().numpy().reshape((1,28,28)) # Pasamos la predección a la CPU y le damos el formato de una imagen de 28x28 píxeles.
# Out:
# imagen.shape=torch.Size([1, 28, 28])

# %%
# Ploteamos una imagen y la correspondiente generada por el modelo.
fig,axes=plt.subplots(1,2)
fig.set_size_inches(10.0,5.0)
ax = axes[0]
ax.axis("off")
ax.imshow(imagen.squeeze(),cmap="gray")
ax = axes[1]
ax.axis("off")
ax.imshow(pred_cpu.squeeze(),cmap="gray")
fig.tight_layout()
#plt.savefig("ggggggggs.jpg",bbox_inches='tight')
plt.savefig('muchascapas.jpg')
plt.show()

# %%
df1 = df.drop("k",1)
#df1
# Out:
# /tmp/ipykernel_138958/4142443721.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df1 = df.drop("k",1)

# %%
df2 = df1.pivot_table(index=["n","epoch"],aggfunc="count").reset_index()
#df2

# %%
df3 = df1.pivot_table(index=["n","epoch"],aggfunc="mean").reset_index()
#df3

# %%
fig,axes=plt.subplots(1,1)
fig.set_size_inches(10.0,5.0)
colors = cm.Dark2.colors
for color,n in zip(colors,df["n"].unique()):
    dfn = df3[df3["n"]==n]
    x = dfn["epoch"]
    ax = axes
    ax.set_xlabel("epoch")
    ax.set_ylabel("loss")
    ax.plot(x,dfn["train_loss"],label=f"entrenamiento n={n}",color=color)
    ax.plot(x,dfn["valid_loss"],label=f"validación n={n}",color='black',linestyle='--')
    ax.legend()
    #ax = axes[1]
    #ax.set_xlabel("epoch")
    #ax.set_ylabel("accuracy")
    #ax.plot(x,dfn["train_accu"],label=f"train n={n}",color=color)
    #ax.plot(x,dfn["valid_accu"],label=f"test n={n}",color='black',linestyle='--')
    #ax.legend()
fig.tight_layout()
plt.savefig('loss_distintascapas.jpg')
plt.show()
