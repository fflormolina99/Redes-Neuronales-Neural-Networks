# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Compose
#from torch.utils.tensorboard import SummaryWriter # TensorBoard support
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import sklearn as skl
import pandas as pd
import time
#from torchviz import make_dot
import torch.optim as optim
from collections import defaultdict
import pickle
import dill
import json
import datetime
from IPython.display import clear_output
torch.set_printoptions(linewidth=120)
torch.set_grad_enabled(True)     # On by default, leave it here for clarity
try:
    import google.colab
    from google.colab import files  
    COLAB = True
except:
    COLAB = False

# %%
#Como siempre chequeamos que este el GPU o el CPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Usando el dispositivo {}'.format(device))
# Out:
# Usando el dispositivo cpu

# %%
# Cargamos los datos de FASHION-MNIST
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}
train_dataset = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)
test_dataset = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %%
# Build the neural network, expand on top of nn.Module
class NetworkRELU(nn.Module):
  def __init__(self):
    super().__init__()

    # define layers
    self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5)
    self.conv2 = nn.Conv2d(in_channels=6, out_channels=12, kernel_size=5)
    
    
    self.fc1 = nn.Linear(in_features=12*4*4, out_features=120)
    self.fc2 = nn.Linear(in_features=120, out_features=60)
    self.out = nn.Linear(in_features=60, out_features=10)
    
    self.dropout = nn.Dropout(p=0.3)

  # define forward function
  def forward(self, t):
    # conv 1
    t = self.conv1(t)
    t = F.relu(t)
    t = F.max_pool2d(t, kernel_size=2, stride=2)

    # conv 2
    t = self.conv2(t)
    t = F.relu(t)
    t = F.max_pool2d(t, kernel_size=2, stride=2)

    # fc1
    t = t.reshape(-1, 12*4*4)
    t = self.fc1(t)
    t = self.dropout(t)
    t = F.relu(t)

    # fc2
    t = self.fc2(t)
    t = self.dropout(t)
    t = F.relu(t)

    # output
    t = self.out(t)
    # don't need softmax here since we'll use cross-entropy as activation.

    return t

# %%
model = NetworkRELU().to(device)
print(model)
# Out:
# NetworkRELU(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 12, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=192, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=60, bias=True)
#   (out): Linear(in_features=60, out_features=10, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %%
# Build the neural network, expand on top of nn.Module
class NetworkLEAKY(nn.Module):
  def __init__(self):
    super().__init__()

    # define layers
    self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5)
    self.conv2 = nn.Conv2d(in_channels=6, out_channels=12, kernel_size=5)
    
    
    self.fc1 = nn.Linear(in_features=12*4*4, out_features=120)
    self.fc2 = nn.Linear(in_features=120, out_features=60)
    self.out = nn.Linear(in_features=60, out_features=10)
    
    self.dropout = nn.Dropout(p=0.3)

  # define forward function
  def forward(self, t):
    # conv 1
    t = self.conv1(t)
    t = F.leaky_relu(t)
    t = F.max_pool2d(t, kernel_size=2, stride=2)

    # conv 2
    t = self.conv2(t)
    t = F.leaky_relu(t)
    t = F.max_pool2d(t, kernel_size=2, stride=2)

    # fc1
    t = t.reshape(-1, 12*4*4)
    t = self.fc1(t)
    t = self.dropout(t)
    t = F.leaky_relu(t)

    # fc2
    t = self.fc2(t)
    t = self.dropout(t)
    t = F.leaky_relu(t)

    # output
    t = self.out(t)
    # don't need softmax here since we'll use cross-entropy as activation.

    return t

# %%
model = NetworkLEAKY().to(device)
print(model)
# Out:
# NetworkLEAKY(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 12, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=192, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=60, bias=True)
#   (out): Linear(in_features=60, out_features=10, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %%
# Definimos la función de entrenamiento
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)

    # Iteramos sobre lotes (batchs)
    for batch, (X, y) in enumerate(dataloader):
        # Calculamos la predicción del modelo y la correspondiente pérdida (error)
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagamos usando el optimizador proveido.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Imprimimos el progreso...
        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            #print(f"batch={batch} loss={loss:>7f}  muestras-procesadas:[{current:>5d}/{size:>5d}]")

# De manera similar, definimos la función de testeo
def test_loop(dataloader,model,loss_fn):
    num_samples  = 0
    num_batches  = 0
    avrg_loss    = 0
    frac_correct = 0
    # Seteamos el modelo en modo evaluacion. Esto sirve para desactivar, por ejemplo, dropout, etc. cuando no estamos en una fase de entrenamiento.
    model.eval()
    # Pasamos el modelo la GPU si está disponible.    
    model = model.to(device)    
    # Para validar, desactivamos el cálculo de gradientes.
    with torch.no_grad():
        # Iteramos sobre lotes (batches)
        for X,y in dataloader:
            # Pasamos los tensores a la GPU si está disponible.
            X = X.to(device)
            y = y.to(device)           
            # Calculamos las predicciones del modelo...
            pred = model(X)
            # y las correspondientes pérdidas (errores), los cuales vamos acumulando en un valor total.
            num_batches += 1
            avrg_loss += loss_fn(pred,y).item()
            # También calculamos el número de predicciones correctas, y lo acumulamos en un total.
            num_samples += y.size(0)            
            frac_correct += (pred.argmax(1)==y).type(torch.float).sum().item()
    # Calculamos la pérdida total y la fracción de clasificaciones correctas, y las imprimimos.
    avrg_loss    /= num_batches
    frac_correct /= num_samples
    #print(f"Test Error: \n Accuracy: {frac_correct:>0.5f}, Avg. loss: {avrg_loss:>8f} \n")
    return avrg_loss,frac_correct

# %% [markdown]
# Creo que sería algo así como:
# modelname[activation]
# En donde querés que aparezca el nombre. Suponete que activation sea =1 entonces eso te va a devolver el segundo valor de modelname (creo que era LeakyRELU)
#
# print( 'Función de activación: {modelname[activation]}')

# %%
# Definimos hiperparámetros de entrenamiento
learning_rate = 1e-3
batch_size = 1000
num_epochs = 50
####################################
model1= NetworkRELU()
model2 = NetworkLEAKY()
modelnames = ["relu","leakyrelu"]

#net1=str(nett1)
#net2=str(nett2)

#model1=net1.replace('NetworkRELU(\n  (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))\n  (conv2): Conv2d(6, 12, kernel_size=(5, 5), stride=(1, 1))\n  (fc1): Linear(in_features=192, out_features=120, bias=True)\n  (fc2): Linear(in_features=120, out_features=60, bias=True)\n  (out): Linear(in_features=60, out_features=10, bias=True)\n  (dropout): Dropout(p=0.3, inplace=False)\n)','RELU')
#model2=net2.replace('NetworkLEAKY(\n  (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))\n  (conv2): Conv2d(6, 12, kernel_size=(5, 5), stride=(1, 1))\n  (fc1): Linear(in_features=192, out_features=120, bias=True)\n  (fc2): Linear(in_features=120, out_features=60, bias=True)\n  (out): Linear(in_features=60, out_features=10, bias=True)\n  (dropout): Dropout(p=0.3, inplace=False)\n)','LeakyRELU')
#####################################
models = [model1,model2]
# Creamos una funcion de perdida
loss_fn = nn.CrossEntropyLoss()
# Creamos un DataFrame de pandas para ir almacenando los valores calculados.
df = pd.DataFrame()
# Simulamos por tramos porque google colab se desconecta antes de que concluya para todos los valores de n en la lista.
for modelnumber,model in enumerate(models):
    # Creamos el modelo y el optimizador
    model = model
    # Creamos los dataloaders ...
    train_dataloader = DataLoader(train_dataset,batch_size=batch_size)
    # ... en particular, usamos el dataset de prueba (test) como dataset de validación
    valid_dataloader = DataLoader(test_dataset,batch_size=batch_size)  
    
    optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate,eps=1e-08,weight_decay=0,amsgrad=False)
    # Entrenamos el modelo y calcualmos curvas.
    min_valid_loss = float("inf")
    for epoch in range(num_epochs):
        train_loop(train_dataloader,model,loss_fn,optimizer)
        train_loss,train_accu = test_loop(train_dataloader,model,loss_fn)
        valid_loss,valid_accu = test_loop(valid_dataloader,model,loss_fn)
        print(f"activation={modelnumber} epoch={epoch} train_loss={train_loss} train_accu={train_accu} valid_loss={valid_loss} valid_accu={valid_accu}")
        df = df.append({"activation":modelnumber,
                        "epoch":epoch,
                        "train_loss":train_loss,
                        "train_accu":train_accu,
                        "valid_loss":valid_loss,
                        "valid_accu":valid_accu}
                        ,ignore_index=True)
json_fname = "simulation-results-"+datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+".json"
df.to_json(json_fname)
if COLAB:
    files.download(json_fname)
# Out:
# activation=0 epoch=0 train_loss=0.9104920486609142 train_accu=0.6591 valid_loss=0.9196349561214447 valid_accu=0.6611
# activation=0 epoch=1 train_loss=0.6574603984753291 train_accu=0.7437 valid_loss=0.6695518434047699 valid_accu=0.7398
# activation=0 epoch=2 train_loss=0.5762130975723266 train_accu=0.7734166666666666 valid_loss=0.5908373594284058 valid_accu=0.7704
# activation=0 epoch=3 train_loss=0.5381596967577934 train_accu=0.7908333333333334 valid_loss=0.5567382395267486 valid_accu=0.7868
# activation=0 epoch=4 train_loss=0.5115199824174245 train_accu=0.8035 valid_loss=0.5327924579381943 valid_accu=0.7953
# activation=0 epoch=5 train_loss=0.48613190005222956 train_accu=0.8162166666666667 valid_loss=0.5093345135450363 valid_accu=0.8081
# activation=0 epoch=6 train_loss=0.4635109802087148 train_accu=0.8264333333333334 valid_loss=0.4882771193981171 valid_accu=0.8183
# activation=0 epoch=7 train_loss=0.4440552587310473 train_accu=0.8372833333333334 valid_loss=0.4696199059486389 valid_accu=0.8285
# activation=0 epoch=8 train_loss=0.42829330960909523 train_accu=0.84435 valid_loss=0.45416914820671084 valid_accu=0.8352
# activation=0 epoch=9 train_loss=0.4145807340741158 train_accu=0.8492666666666666 valid_loss=0.4409331679344177 valid_accu=0.8419
# activation=0 epoch=10 train_loss=0.40204899162054064 train_accu=0.8538 valid_loss=0.42895804047584535 valid_accu=0.8456
# activation=0 epoch=11 train_loss=0.3924231459697088 train_accu=0.8575166666666667 valid_loss=0.42009363174438474 valid_accu=0.8491
# activation=0 epoch=12 train_loss=0.38374981383482615 train_accu=0.8608 valid_loss=0.41172823011875154 valid_accu=0.851
# activation=0 epoch=13 train_loss=0.375531360010306 train_accu=0.8639 valid_loss=0.4035744369029999 valid_accu=0.8537
# activation=0 epoch=14 train_loss=0.36918350905179975 train_accu=0.8659166666666667 valid_loss=0.3975889146327972 valid_accu=0.856
# activation=0 epoch=15 train_loss=0.3634336367249489 train_accu=0.8677666666666667 valid_loss=0.3920638769865036 valid_accu=0.8576
# activation=0 epoch=16 train_loss=0.3580115253726641 train_accu=0.86905 valid_loss=0.38711251616477965 valid_accu=0.8581
# activation=0 epoch=17 train_loss=0.3537521854043007 train_accu=0.8708 valid_loss=0.3831820249557495 valid_accu=0.8599
# activation=0 epoch=18 train_loss=0.347156552473704 train_accu=0.8735666666666667 valid_loss=0.37699303328990935 valid_accu=0.8626
# activation=0 epoch=19 train_loss=0.340979761381944 train_accu=0.8755833333333334 valid_loss=0.37131704986095426 valid_accu=0.8657
# activation=0 epoch=20 train_loss=0.3363146682580312 train_accu=0.8774 valid_loss=0.36712775826454164 valid_accu=0.8678
# activation=0 epoch=21 train_loss=0.3322977935274442 train_accu=0.8790333333333333 valid_loss=0.3638218313455582 valid_accu=0.87
# activation=0 epoch=22 train_loss=0.3293374295035998 train_accu=0.8797333333333334 valid_loss=0.3614524692296982 valid_accu=0.8706
# activation=0 epoch=23 train_loss=0.32721037914355594 train_accu=0.8803 valid_loss=0.360055735707283 valid_accu=0.8698
# activation=0 epoch=24 train_loss=0.3262206380565961 train_accu=0.88065 valid_loss=0.35988428592681887 valid_accu=0.8693
# activation=0 epoch=25 train_loss=0.32428853660821916 train_accu=0.88075 valid_loss=0.3585669666528702 valid_accu=0.8688
# activation=0 epoch=26 train_loss=0.31914774427811304 train_accu=0.8828833333333334 valid_loss=0.353821137547493 valid_accu=0.872
# activation=0 epoch=27 train_loss=0.31374197055896125 train_accu=0.8846166666666667 valid_loss=0.34899779558181765 valid_accu=0.8733
# activation=0 epoch=28 train_loss=0.30998021314541496 train_accu=0.8862166666666667 valid_loss=0.3462373286485672 valid_accu=0.8747
# activation=0 epoch=29 train_loss=0.306961781779925 train_accu=0.8874333333333333 valid_loss=0.34392266273498534 valid_accu=0.8751
# activation=0 epoch=30 train_loss=0.3035902589559555 train_accu=0.8887333333333334 valid_loss=0.3412120133638382 valid_accu=0.8759
# activation=0 epoch=31 train_loss=0.3003436759114265 train_accu=0.89055 valid_loss=0.33869806826114657 valid_accu=0.877
# activation=0 epoch=32 train_loss=0.29721686293681465 train_accu=0.8916666666666667 valid_loss=0.3365085482597351 valid_accu=0.8778
# activation=0 epoch=33 train_loss=0.2938085481524467 train_accu=0.8923833333333333 valid_loss=0.33409456014633176 valid_accu=0.8796
# activation=0 epoch=34 train_loss=0.29076225658257804 train_accu=0.8934666666666666 valid_loss=0.33217231631278993 valid_accu=0.8802
# activation=0 epoch=35 train_loss=0.2878351479768753 train_accu=0.8947833333333334 valid_loss=0.32995347380638124 valid_accu=0.8814
# activation=0 epoch=36 train_loss=0.2845219631989797 train_accu=0.8960333333333333 valid_loss=0.32761881947517396 valid_accu=0.8821
# activation=0 epoch=37 train_loss=0.2816589646041393 train_accu=0.8972833333333333 valid_loss=0.325710067152977 valid_accu=0.8838
# activation=0 epoch=38 train_loss=0.2785310501853625 train_accu=0.8982166666666667 valid_loss=0.32368259131908417 valid_accu=0.8842
# activation=0 epoch=39 train_loss=0.2761203336218993 train_accu=0.89895 valid_loss=0.3220625936985016 valid_accu=0.8846
# activation=0 epoch=40 train_loss=0.27337843080361685 train_accu=0.9 valid_loss=0.32018336951732634 valid_accu=0.8854
# activation=0 epoch=41 train_loss=0.2710996905962626 train_accu=0.9008666666666667 valid_loss=0.31877816319465635 valid_accu=0.8863
# activation=0 epoch=42 train_loss=0.2690422629316648 train_accu=0.9017333333333334 valid_loss=0.3176354348659515 valid_accu=0.8872
# activation=0 epoch=43 train_loss=0.2667519174516201 train_accu=0.9027 valid_loss=0.3162221223115921 valid_accu=0.8871
# activation=0 epoch=44 train_loss=0.2647687589128812 train_accu=0.9033333333333333 valid_loss=0.3151249587535858 valid_accu=0.8877
# activation=0 epoch=45 train_loss=0.2627110483745734 train_accu=0.9043 valid_loss=0.3139281183481216 valid_accu=0.8885
# activation=0 epoch=46 train_loss=0.2604256557921569 train_accu=0.9055166666666666 valid_loss=0.3127982199192047 valid_accu=0.8884
# activation=0 epoch=47 train_loss=0.25808778405189514 train_accu=0.9058 valid_loss=0.31163803935050965 valid_accu=0.8888
# activation=0 epoch=48 train_loss=0.2565513767302036 train_accu=0.9065166666666666 valid_loss=0.3107964783906937 valid_accu=0.8889
# activation=0 epoch=49 train_loss=0.25453787446022036 train_accu=0.9072333333333333 valid_loss=0.30957532823085787 valid_accu=0.8885
# activation=1 epoch=0 train_loss=0.8675364404916763 train_accu=0.682 valid_loss=0.8825202107429504 valid_accu=0.6766
# activation=1 epoch=1 train_loss=0.6284627795219422 train_accu=0.7547666666666667 valid_loss=0.6441855311393738 valid_accu=0.7506
# activation=1 epoch=2 train_loss=0.5649202321966489 train_accu=0.78215 valid_loss=0.5797763288021087 valid_accu=0.7785
# activation=1 epoch=3 train_loss=0.5259232307473819 train_accu=0.7989666666666667 valid_loss=0.541971492767334 valid_accu=0.7946
# activation=1 epoch=4 train_loss=0.5028973743319511 train_accu=0.81165 valid_loss=0.5204040676355361 valid_accu=0.8065
# activation=1 epoch=5 train_loss=0.4800622249643008 train_accu=0.8243666666666667 valid_loss=0.4998840898275375 valid_accu=0.8181
# activation=1 epoch=6 train_loss=0.45761311451594033 train_accu=0.83395 valid_loss=0.47971259951591494 valid_accu=0.8266
# activation=1 epoch=7 train_loss=0.4374737933278084 train_accu=0.8420666666666666 valid_loss=0.4610990583896637 valid_accu=0.8334
# activation=1 epoch=8 train_loss=0.42571786095698677 train_accu=0.8467166666666667 valid_loss=0.45050964057445525 valid_accu=0.8369
# activation=1 epoch=9 train_loss=0.4155004595716794 train_accu=0.8492333333333333 valid_loss=0.44135657250881194 valid_accu=0.8399
# activation=1 epoch=10 train_loss=0.40140416771173476 train_accu=0.8545 valid_loss=0.4282728374004364 valid_accu=0.8451
# activation=1 epoch=11 train_loss=0.38885794778664906 train_accu=0.8592166666666666 valid_loss=0.41647868752479555 valid_accu=0.8499
# activation=1 epoch=12 train_loss=0.37615367223819096 train_accu=0.8645333333333334 valid_loss=0.40411461889743805 valid_accu=0.8557
# activation=1 epoch=13 train_loss=0.36573163072268167 train_accu=0.8693 valid_loss=0.3941877692937851 valid_accu=0.8602
# activation=1 epoch=14 train_loss=0.36095972955226896 train_accu=0.87055 valid_loss=0.3904725730419159 valid_accu=0.8589
# activation=1 epoch=15 train_loss=0.357188048462073 train_accu=0.8718833333333333 valid_loss=0.387635201215744 valid_accu=0.8605
# activation=1 epoch=16 train_loss=0.35008935580650963 train_accu=0.8743 valid_loss=0.38186842799186704 valid_accu=0.8626
# activation=1 epoch=17 train_loss=0.3433497210343679 train_accu=0.87665 valid_loss=0.375425186753273 valid_accu=0.866
# activation=1 epoch=18 train_loss=0.33742577334245044 train_accu=0.8783 valid_loss=0.37072798013687136 valid_accu=0.8673
# activation=1 epoch=19 train_loss=0.332578972975413 train_accu=0.8799333333333333 valid_loss=0.3666084915399551 valid_accu=0.8691
# activation=1 epoch=20 train_loss=0.3273318340380987 train_accu=0.8820833333333333 valid_loss=0.3625210374593735 valid_accu=0.8701
# activation=1 epoch=21 train_loss=0.32254277219374977 train_accu=0.8834 valid_loss=0.3583593308925629 valid_accu=0.8719
# activation=1 epoch=22 train_loss=0.3184736594557762 train_accu=0.88445 valid_loss=0.3549062550067902 valid_accu=0.8738
# activation=1 epoch=23 train_loss=0.3148906995852788 train_accu=0.8855333333333333 valid_loss=0.3520607352256775 valid_accu=0.8756
# activation=1 epoch=24 train_loss=0.31054811775684354 train_accu=0.8873833333333333 valid_loss=0.34858918488025664 valid_accu=0.8769
# activation=1 epoch=25 train_loss=0.30729345629612603 train_accu=0.8884333333333333 valid_loss=0.34589488208293917 valid_accu=0.8777
# activation=1 epoch=26 train_loss=0.30437927891810734 train_accu=0.8895833333333333 valid_loss=0.3439663738012314 valid_accu=0.8778
# activation=1 epoch=27 train_loss=0.30050937632719676 train_accu=0.8908 valid_loss=0.34119461476802826 valid_accu=0.8786
# activation=1 epoch=28 train_loss=0.29725469325979553 train_accu=0.8919666666666667 valid_loss=0.3389245837926865 valid_accu=0.88
# activation=1 epoch=29 train_loss=0.29437802359461784 train_accu=0.8923833333333333 valid_loss=0.33603653609752654 valid_accu=0.8801
# activation=1 epoch=30 train_loss=0.29209822217623393 train_accu=0.89335 valid_loss=0.3350478380918503 valid_accu=0.881
# activation=1 epoch=31 train_loss=0.2906403568883737 train_accu=0.8942 valid_loss=0.33404568731784823 valid_accu=0.8815
# activation=1 epoch=32 train_loss=0.28676113759477934 train_accu=0.8960333333333333 valid_loss=0.3317549556493759 valid_accu=0.8819
# activation=1 epoch=33 train_loss=0.28379839236537613 train_accu=0.89665 valid_loss=0.3298435598611832 valid_accu=0.8824
# activation=1 epoch=34 train_loss=0.2792922412355741 train_accu=0.8977 valid_loss=0.32617159783840177 valid_accu=0.8831
# activation=1 epoch=35 train_loss=0.2758493448297183 train_accu=0.8987833333333334 valid_loss=0.3240158975124359 valid_accu=0.8836
# activation=1 epoch=36 train_loss=0.274793886890014 train_accu=0.8989666666666667 valid_loss=0.3242243230342865 valid_accu=0.884
# activation=1 epoch=37 train_loss=0.27248046845197677 train_accu=0.89965 valid_loss=0.3232244461774826 valid_accu=0.884
# activation=1 epoch=38 train_loss=0.2694713269670804 train_accu=0.9008166666666667 valid_loss=0.3212427914142609 valid_accu=0.8851
# activation=1 epoch=39 train_loss=0.26665170192718507 train_accu=0.90175 valid_loss=0.31998205482959746 valid_accu=0.8846
# activation=1 epoch=40 train_loss=0.264057162652413 train_accu=0.9029 valid_loss=0.3189518183469772 valid_accu=0.885
# activation=1 epoch=41 train_loss=0.26178596665461856 train_accu=0.9035666666666666 valid_loss=0.3180974036455154 valid_accu=0.8865
# activation=1 epoch=42 train_loss=0.259433904538552 train_accu=0.9044666666666666 valid_loss=0.31692119836807253 valid_accu=0.8868
# activation=1 epoch=43 train_loss=0.25811299731334053 train_accu=0.9049333333333334 valid_loss=0.3168284773826599 valid_accu=0.8865
# activation=1 epoch=44 train_loss=0.25564161588748296 train_accu=0.9061666666666667 valid_loss=0.31559590995311737 valid_accu=0.887
# activation=1 epoch=45 train_loss=0.2532964321474234 train_accu=0.9067333333333333 valid_loss=0.3141623973846436 valid_accu=0.8876
# activation=1 epoch=46 train_loss=0.2510137048860391 train_accu=0.9076166666666666 valid_loss=0.3136243224143982 valid_accu=0.888
# activation=1 epoch=47 train_loss=0.2495642952620983 train_accu=0.9080833333333334 valid_loss=0.3132168412208557 valid_accu=0.8881
# activation=1 epoch=48 train_loss=0.2467446359495322 train_accu=0.9086333333333333 valid_loss=0.31141831576824186 valid_accu=0.8886
# activation=1 epoch=49 train_loss=0.2446759171783924 train_accu=0.9094333333333333 valid_loss=0.31097598671913146 valid_accu=0.8888

# %%
idx_rename = {"0.0":'ReLU', 
              "1.0":'LeakyReLU'}

# %%
df_s = df.rename(index=idx_rename)
df_s.head()
# Out:
#    activation  epoch  train_loss  train_accu  valid_loss  valid_accu
# 0         0.0    0.0    0.910492    0.659100    0.919635      0.6611
# 1         0.0    1.0    0.657460    0.743700    0.669552      0.7398
# 2         0.0    2.0    0.576213    0.773417    0.590837      0.7704
# 3         0.0    3.0    0.538160    0.790833    0.556738      0.7868
# 4         0.0    4.0    0.511520    0.803500    0.532792      0.7953

# %%
df2 = df.pivot_table(index=["activation","epoch"],aggfunc="count").reset_index()
#df2

# %%
df3 = df.pivot_table(index=["activation","epoch"],aggfunc="mean").reset_index()
#df3

# %%
df3
# Out:
#     activation  epoch  train_accu  train_loss  valid_accu  valid_loss
# 0          0.0    0.0    0.659100    0.910492      0.6611    0.919635
# 1          0.0    1.0    0.743700    0.657460      0.7398    0.669552
# 2          0.0    2.0    0.773417    0.576213      0.7704    0.590837
# 3          0.0    3.0    0.790833    0.538160      0.7868    0.556738
# 4          0.0    4.0    0.803500    0.511520      0.7953    0.532792
# ..         ...    ...         ...         ...         ...         ...
# 95         1.0   45.0    0.906733    0.253296      0.8876    0.314162
# 96         1.0   46.0    0.907617    0.251014      0.8880    0.313624
# 97         1.0   47.0    0.908083    0.249564      0.8881    0.313217
# 98         1.0   48.0    0.908633    0.246745      0.8886    0.311418
# 99         1.0   49.0    0.909433    0.244676      0.8888    0.310976
#
# [100 rows x 6 columns]

# %%
fig,axes=plt.subplots(2,1)
fig.set_size_inches(5.0,10.0)
colors = cm.Dark2.colors
for color,activation in zip(colors,df["activation"].unique()):
    dfn = df3[df3["activation"]==activation]
    x = dfn["epoch"]
    ax = axes[0]
    ax.set_xlabel("epoch")
    ax.set_ylabel("loss")
    ax.plot(x,dfn["train_loss"],label=f"train activation={activation}",color=color)
    ax.plot(x,dfn["valid_loss"],label=f"valid activation={activation}",color=color,linestyle='--')
    ax.legend()
    ax = axes[1]
    ax.set_xlabel("epoch")
    ax.set_ylabel("accuracy")
    ax.plot(x,dfn["train_accu"],label=f"train activation={activation}",color=color)
    ax.plot(x,dfn["valid_accu"],label=f"test activation={activation}",color=color,linestyle='--')
    ax.legend()
fig.tight_layout()
plt.savefig("dif_activations1.pdf")
plt.show()

# %% [markdown]
# La mejor funcion de activacion es la Leaky ReLU
