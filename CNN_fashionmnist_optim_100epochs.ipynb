# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Compose
#from torch.utils.tensorboard import SummaryWriter # TensorBoard support
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import sklearn as skl
import pandas as pd
import time
#from torchviz import make_dot
import torch.optim as optim
from collections import defaultdict
import pickle
import dill
import json
import datetime
from IPython.display import clear_output
torch.set_printoptions(linewidth=120)
torch.set_grad_enabled(True)     # On by default, leave it here for clarity
try:
    import google.colab
    from google.colab import files  
    COLAB = True
except:
    COLAB = False

# %%
#Como siempre chequeamos que este el GPU o el CPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Usando el dispositivo {}'.format(device))
# Out:
# Usando el dispositivo cpu

# %%
# Cargamos los datos de FASHION-MNIST
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}
train_dataset = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)
test_dataset = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %%
# Build the neural network, expand on top of nn.Module
class Network(nn.Module):
  def __init__(self):
    super().__init__()

    # define layers
    self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5)
    self.conv2 = nn.Conv2d(in_channels=6, out_channels=12, kernel_size=5)
    
    
    self.fc1 = nn.Linear(in_features=12*4*4, out_features=120)
    self.fc2 = nn.Linear(in_features=120, out_features=60)
    self.out = nn.Linear(in_features=60, out_features=10)
    
    self.dropout = nn.Dropout(p=0.3)

  # define forward function
  def forward(self, t):
    # conv 1
    t = self.conv1(t)
    t = F.leaky_relu(t)
    t = F.max_pool2d(t, kernel_size=2, stride=2)

    # conv 2
    t = self.conv2(t)
    t = F.leaky_relu(t)
    t = F.max_pool2d(t, kernel_size=2, stride=2)

    # fc1
    t = t.reshape(-1, 12*4*4)
    t = self.fc1(t)
    t = self.dropout(t)
    t = F.leaky_relu(t)

    # fc2
    t = self.fc2(t)
    t = self.dropout(t)
    t = F.leaky_relu(t)

    # output
    t = self.out(t)
    # don't need softmax here since we'll use cross-entropy as activation.

    return t

# %%
# Definimos la función de entrenamiento
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)

    # Iteramos sobre lotes (batchs)
    for batch, (X, y) in enumerate(dataloader):
        # Calculamos la predicción del modelo y la correspondiente pérdida (error)
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagamos usando el optimizador proveido.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Imprimimos el progreso...
        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            #print(f"batch={batch} loss={loss:>7f}  muestras-procesadas:[{current:>5d}/{size:>5d}]")

# De manera similar, definimos la función de testeo
def test_loop(dataloader,model,loss_fn):
    num_samples  = 0
    num_batches  = 0
    avrg_loss    = 0
    frac_correct = 0
    # Seteamos el modelo en modo evaluacion. Esto sirve para desactivar, por ejemplo, dropout, etc. cuando no estamos en una fase de entrenamiento.
    model.eval()
    # Pasamos el modelo la GPU si está disponible.    
    model = model.to(device)    
    # Para validar, desactivamos el cálculo de gradientes.
    with torch.no_grad():
        # Iteramos sobre lotes (batches)
        for X,y in dataloader:
            # Pasamos los tensores a la GPU si está disponible.
            X = X.to(device)
            y = y.to(device)           
            # Calculamos las predicciones del modelo...
            pred = model(X)
            # y las correspondientes pérdidas (errores), los cuales vamos acumulando en un valor total.
            num_batches += 1
            avrg_loss += loss_fn(pred,y).item()
            # También calculamos el número de predicciones correctas, y lo acumulamos en un total.
            num_samples += y.size(0)            
            frac_correct += (pred.argmax(1)==y).type(torch.float).sum().item()
    # Calculamos la pérdida total y la fracción de clasificaciones correctas, y las imprimimos.
    avrg_loss    /= num_batches
    frac_correct /= num_samples
    #print(f"Test Error: \n Accuracy: {frac_correct:>0.5f}, Avg. loss: {avrg_loss:>8f} \n")
    return avrg_loss,frac_correct

# %%
# Definimos hiperparámetros de entrenamiento
learning_rate = 1e-3
batch_size = 1000
num_epochs = 100
num_k = 1 #72
n=10 # Recordar que 28*28=784
# Creamos una funcion de perdida
loss_fn = nn.CrossEntropyLoss()
# Creamos un DataFrame de pandas para ir almacenando los valores calculados.
df = pd.DataFrame()
# Simulamos por tramos porque google colab se desconecta antes de que concluya para todos los valores de n en la lista.
#for p in dropouts:
#for k in range(num_k):
# Creamos el modelo y el optimzador
model = Network()
# Creamos los dataloaders ...
train_dataloader = DataLoader(train_dataset,batch_size=batch_size)
# ... en particular, usamos el dataset de prueba (test) como dataset de validación
valid_dataloader = DataLoader(test_dataset,batch_size=batch_size)         
#optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate)
optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate,eps=1e-08,weight_decay=0,amsgrad=False)
# Entrenamos el modelo y calcualmos curvas.
min_valid_loss = float("inf")
for epoch in range(num_epochs):
    train_loop(train_dataloader,model,loss_fn,optimizer)
    train_loss,train_accu = test_loop(train_dataloader,model,loss_fn)
    valid_loss,valid_accu = test_loop(valid_dataloader,model,loss_fn)
    print(f"epoch={epoch} train_loss={train_loss} train_accu={train_accu} valid_loss={valid_loss} valid_accu={valid_accu}")
    df = df.append({"epoch":epoch,
                    "train_loss":train_loss,
                    "train_accu":train_accu,
                    "valid_loss":valid_loss,
                    "valid_accu":valid_accu}
                    ,ignore_index=True)
json_fname = "simulation-results-"+datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+".json"
df.to_json(json_fname)
if COLAB:
    files.download(json_fname)
# Out:
# epoch=0 train_loss=0.8540436685085296 train_accu=0.6931 valid_loss=0.8673084914684296 valid_accu=0.6867
# epoch=1 train_loss=0.6382745693127314 train_accu=0.7581166666666667 valid_loss=0.6582618594169617 valid_accu=0.7554
# epoch=2 train_loss=0.5630391910672188 train_accu=0.78325 valid_loss=0.583139568567276 valid_accu=0.7744
# epoch=3 train_loss=0.5251539319753646 train_accu=0.7981333333333334 valid_loss=0.5462166249752045 valid_accu=0.7871
# epoch=4 train_loss=0.49570609579483665 train_accu=0.8093333333333333 valid_loss=0.5179105848073959 valid_accu=0.8003
# epoch=5 train_loss=0.47130900422732036 train_accu=0.8228666666666666 valid_loss=0.4951199620962143 valid_accu=0.8152
# epoch=6 train_loss=0.4505234072605769 train_accu=0.83665 valid_loss=0.47616235017776487 valid_accu=0.8262
# epoch=7 train_loss=0.432453786333402 train_accu=0.8438666666666667 valid_loss=0.459706062078476 valid_accu=0.8331
# epoch=8 train_loss=0.41724281311035155 train_accu=0.8499666666666666 valid_loss=0.44590888917446136 valid_accu=0.8396
# epoch=9 train_loss=0.4022428130110105 train_accu=0.85475 valid_loss=0.43173292875289915 valid_accu=0.8461
# epoch=10 train_loss=0.3899198810259501 train_accu=0.8595 valid_loss=0.41973654329776766 valid_accu=0.8509
# epoch=11 train_loss=0.37996839930613835 train_accu=0.8621166666666666 valid_loss=0.40984130203723906 valid_accu=0.8522
# epoch=12 train_loss=0.3729504893223445 train_accu=0.8642 valid_loss=0.4036515146493912 valid_accu=0.8555
# epoch=13 train_loss=0.35706509749094645 train_accu=0.8705666666666667 valid_loss=0.38856603503227233 valid_accu=0.8576
# epoch=14 train_loss=0.3484854136904081 train_accu=0.8729 valid_loss=0.38152946531772614 valid_accu=0.8606
# epoch=15 train_loss=0.34172297914822897 train_accu=0.8745 valid_loss=0.37578485906124115 valid_accu=0.8618
# epoch=16 train_loss=0.3343477452794711 train_accu=0.8778166666666667 valid_loss=0.3700273871421814 valid_accu=0.8651
# epoch=17 train_loss=0.3283264001210531 train_accu=0.87985 valid_loss=0.36449060440063474 valid_accu=0.867
# epoch=18 train_loss=0.3230332444111506 train_accu=0.8816666666666667 valid_loss=0.36017277240753176 valid_accu=0.8705
# epoch=19 train_loss=0.3175896028677622 train_accu=0.8839 valid_loss=0.3557336777448654 valid_accu=0.8716
# epoch=20 train_loss=0.31214550882577896 train_accu=0.8855333333333333 valid_loss=0.3512096256017685 valid_accu=0.8734
# epoch=21 train_loss=0.3069713349143664 train_accu=0.8875166666666666 valid_loss=0.34695354104042053 valid_accu=0.8734
# epoch=22 train_loss=0.3018355498711268 train_accu=0.8894 valid_loss=0.34302615821361543 valid_accu=0.8748
# epoch=23 train_loss=0.2974824830889702 train_accu=0.8911 valid_loss=0.33981568813323976 valid_accu=0.8764
# epoch=24 train_loss=0.29325949450333916 train_accu=0.8921333333333333 valid_loss=0.3368138551712036 valid_accu=0.877
# epoch=25 train_loss=0.28908326824506125 train_accu=0.8940833333333333 valid_loss=0.33365617096424105 valid_accu=0.8772
# epoch=26 train_loss=0.2852987475693226 train_accu=0.8956333333333333 valid_loss=0.33079141080379487 valid_accu=0.8789
# epoch=27 train_loss=0.2814419207473596 train_accu=0.8974833333333333 valid_loss=0.3282609790563583 valid_accu=0.8811
# epoch=28 train_loss=0.2782810586194197 train_accu=0.8984666666666666 valid_loss=0.32610011398792266 valid_accu=0.8816
# epoch=29 train_loss=0.2752406343817711 train_accu=0.8994333333333333 valid_loss=0.3243143707513809 valid_accu=0.8829
# epoch=30 train_loss=0.27198576281468073 train_accu=0.9004166666666666 valid_loss=0.32212080657482145 valid_accu=0.8829
# epoch=31 train_loss=0.26933312540253 train_accu=0.9012666666666667 valid_loss=0.3205107033252716 valid_accu=0.883
# epoch=32 train_loss=0.2668634248276552 train_accu=0.9022166666666667 valid_loss=0.31867981553077696 valid_accu=0.8841
# epoch=33 train_loss=0.26445665260156 train_accu=0.90325 valid_loss=0.3172469824552536 valid_accu=0.8844
# epoch=34 train_loss=0.2622000334163507 train_accu=0.90405 valid_loss=0.31604449450969696 valid_accu=0.885
# epoch=35 train_loss=0.25985968932509423 train_accu=0.9046833333333333 valid_loss=0.31516167521476746 valid_accu=0.8858
# epoch=36 train_loss=0.2579468756914139 train_accu=0.9054666666666666 valid_loss=0.314351299405098 valid_accu=0.8861
# epoch=37 train_loss=0.2557784140110016 train_accu=0.9057833333333334 valid_loss=0.31328096687793733 valid_accu=0.8858
# epoch=38 train_loss=0.25364975159366926 train_accu=0.9068 valid_loss=0.3122746407985687 valid_accu=0.8867
# epoch=39 train_loss=0.252402825653553 train_accu=0.9070166666666667 valid_loss=0.3119424134492874 valid_accu=0.8864
# epoch=40 train_loss=0.2501387869318326 train_accu=0.9077 valid_loss=0.3111235201358795 valid_accu=0.8866
# epoch=41 train_loss=0.24714324747522673 train_accu=0.90915 valid_loss=0.30970335006713867 valid_accu=0.8873
# epoch=42 train_loss=0.2456845132013162 train_accu=0.9095333333333333 valid_loss=0.30939880609512327 valid_accu=0.8876
# epoch=43 train_loss=0.24386145944396656 train_accu=0.91035 valid_loss=0.3090291559696198 valid_accu=0.8879
# epoch=44 train_loss=0.24165967429677646 train_accu=0.9111833333333333 valid_loss=0.3085301160812378 valid_accu=0.8877
# epoch=45 train_loss=0.23982671226064364 train_accu=0.9119833333333334 valid_loss=0.3080339848995209 valid_accu=0.8893
# epoch=46 train_loss=0.23827449132998785 train_accu=0.9125666666666666 valid_loss=0.3078821450471878 valid_accu=0.8886
# epoch=47 train_loss=0.2370567224919796 train_accu=0.9129833333333334 valid_loss=0.3083504945039749 valid_accu=0.8878
# epoch=48 train_loss=0.23366299172242483 train_accu=0.9142333333333333 valid_loss=0.3062431126832962 valid_accu=0.8897
# epoch=49 train_loss=0.2317837563653787 train_accu=0.9147666666666666 valid_loss=0.30577164590358735 valid_accu=0.8898
# epoch=50 train_loss=0.229972555488348 train_accu=0.9150833333333334 valid_loss=0.3053899735212326 valid_accu=0.89
# epoch=51 train_loss=0.22744884366790455 train_accu=0.9158666666666667 valid_loss=0.3040401875972748 valid_accu=0.8909
# epoch=52 train_loss=0.2259556273619334 train_accu=0.9166166666666666 valid_loss=0.30396370887756347 valid_accu=0.8915
# epoch=53 train_loss=0.22440863748391468 train_accu=0.9171333333333334 valid_loss=0.3038173198699951 valid_accu=0.8908
# epoch=54 train_loss=0.22251822799444199 train_accu=0.9177833333333333 valid_loss=0.30334077775478363 valid_accu=0.8911
# epoch=55 train_loss=0.21997226377328236 train_accu=0.91865 valid_loss=0.3021980196237564 valid_accu=0.8918
# epoch=56 train_loss=0.21876489768425625 train_accu=0.9187166666666666 valid_loss=0.3026318609714508 valid_accu=0.8913
# epoch=57 train_loss=0.2181427386899789 train_accu=0.9187166666666666 valid_loss=0.30322388708591463 valid_accu=0.8912
# epoch=58 train_loss=0.216035200158755 train_accu=0.9195666666666666 valid_loss=0.3028343379497528 valid_accu=0.8911
# epoch=59 train_loss=0.21448222175240517 train_accu=0.9205666666666666 valid_loss=0.30280994176864623 valid_accu=0.8922
# epoch=60 train_loss=0.21366608912746113 train_accu=0.9207 valid_loss=0.303727850317955 valid_accu=0.8914
# epoch=61 train_loss=0.21203586210807165 train_accu=0.9207833333333333 valid_loss=0.30342029333114623 valid_accu=0.892
# epoch=62 train_loss=0.2101572578152021 train_accu=0.9217333333333333 valid_loss=0.3036074608564377 valid_accu=0.8918
# epoch=63 train_loss=0.20725998332103093 train_accu=0.9228 valid_loss=0.3024619370698929 valid_accu=0.8919
# epoch=64 train_loss=0.2063266823689143 train_accu=0.9229333333333334 valid_loss=0.30304000079631804 valid_accu=0.893
# epoch=65 train_loss=0.20457522918780643 train_accu=0.9235666666666666 valid_loss=0.3031306266784668 valid_accu=0.8932
# epoch=66 train_loss=0.20392348989844322 train_accu=0.92385 valid_loss=0.3046899110078812 valid_accu=0.8928
# epoch=67 train_loss=0.20270690644780795 train_accu=0.9240333333333334 valid_loss=0.30512998402118685 valid_accu=0.8933
# epoch=68 train_loss=0.2017892725765705 train_accu=0.9244833333333333 valid_loss=0.30567002296447754 valid_accu=0.8923
# epoch=69 train_loss=0.20122197791934013 train_accu=0.9246833333333333 valid_loss=0.30748708844184874 valid_accu=0.8923
# epoch=70 train_loss=0.20014879579345385 train_accu=0.9252 valid_loss=0.30833153128623964 valid_accu=0.8929
# epoch=71 train_loss=0.19953708002964657 train_accu=0.9251833333333334 valid_loss=0.3094557553529739 valid_accu=0.8936
# epoch=72 train_loss=0.19837505742907524 train_accu=0.92535 valid_loss=0.31045637726783754 valid_accu=0.8923
# epoch=73 train_loss=0.19751821781198184 train_accu=0.9257333333333333 valid_loss=0.31120696663856506 valid_accu=0.8931
# epoch=74 train_loss=0.19631178056200346 train_accu=0.9260166666666667 valid_loss=0.3124359607696533 valid_accu=0.8932
# epoch=75 train_loss=0.19490295375386874 train_accu=0.9266333333333333 valid_loss=0.31243994534015657 valid_accu=0.8936
# epoch=76 train_loss=0.19372276465098062 train_accu=0.9268666666666666 valid_loss=0.3132882952690125 valid_accu=0.893
# epoch=77 train_loss=0.19275587623318036 train_accu=0.9274666666666667 valid_loss=0.314376512169838 valid_accu=0.893
# epoch=78 train_loss=0.19266612455248833 train_accu=0.9270333333333334 valid_loss=0.31683775782585144 valid_accu=0.8923
# epoch=79 train_loss=0.19159342075387636 train_accu=0.9273833333333333 valid_loss=0.31776331067085267 valid_accu=0.8925
# epoch=80 train_loss=0.1907466563085715 train_accu=0.9277166666666666 valid_loss=0.3185905635356903 valid_accu=0.8925
# epoch=81 train_loss=0.1892655390004317 train_accu=0.9286 valid_loss=0.31924968361854555 valid_accu=0.8925
# epoch=82 train_loss=0.1805640752116839 train_accu=0.9325833333333333 valid_loss=0.30905506312847136 valid_accu=0.8952
# epoch=83 train_loss=0.1855528858800729 train_accu=0.9299333333333333 valid_loss=0.3123615175485611 valid_accu=0.8918
# epoch=84 train_loss=0.18234778866171836 train_accu=0.9309333333333333 valid_loss=0.31181358397006986 valid_accu=0.892
# epoch=85 train_loss=0.18355713387330372 train_accu=0.9307666666666666 valid_loss=0.31509950160980227 valid_accu=0.891
# epoch=86 train_loss=0.18306169162193933 train_accu=0.9312 valid_loss=0.3174404472112656 valid_accu=0.8916
# epoch=87 train_loss=0.18234389573335646 train_accu=0.9311 valid_loss=0.317832413315773 valid_accu=0.8913
# epoch=88 train_loss=0.18439221754670143 train_accu=0.9293666666666667 valid_loss=0.3208689153194427 valid_accu=0.8921
# epoch=89 train_loss=0.18847953279813132 train_accu=0.928 valid_loss=0.32716200351715086 valid_accu=0.8894
# epoch=90 train_loss=0.19336567670106888 train_accu=0.9257333333333333 valid_loss=0.3344365030527115 valid_accu=0.8899
# epoch=91 train_loss=0.19403943916161856 train_accu=0.9265 valid_loss=0.3373680770397186 valid_accu=0.8879
# epoch=92 train_loss=0.18843565707405407 train_accu=0.9281666666666667 valid_loss=0.3330732941627502 valid_accu=0.8901
# epoch=93 train_loss=0.18592161436875662 train_accu=0.92875 valid_loss=0.33222638368606566 valid_accu=0.8912
# epoch=94 train_loss=0.1908321095009645 train_accu=0.927 valid_loss=0.3379743456840515 valid_accu=0.8891
# epoch=95 train_loss=0.19436200335621834 train_accu=0.9260333333333334 valid_loss=0.3429647207260132 valid_accu=0.8894
# epoch=96 train_loss=0.19361711765329043 train_accu=0.9262833333333333 valid_loss=0.3438424438238144 valid_accu=0.8904
# epoch=97 train_loss=0.18668531651298206 train_accu=0.9291333333333334 valid_loss=0.33855661153793337 valid_accu=0.8917
# epoch=98 train_loss=0.1791792762776216 train_accu=0.9322333333333334 valid_loss=0.33351399302482604 valid_accu=0.8934
# epoch=99 train_loss=0.17317769850293796 train_accu=0.9347333333333333 valid_loss=0.3286289066076279 valid_accu=0.8938

# %%
df2 = df.pivot_table(index=["epoch"],aggfunc="count").reset_index()
#df2

# %%
df3 = df.pivot_table(index=["epoch"],aggfunc="mean").reset_index()
#df3

# %%
fig,axes=plt.subplots(2,1)
fig.set_size_inches(5.0,10.0)
colors = cm.Dark2.colors
#for color,p in zip(colors,df["p"].unique()):
#    dfn = df3[df3["p"]==p]
x = df3["epoch"]
ax = axes[0]
ax.set_xlabel("epoch")
ax.set_ylabel("loss")
ax.plot(x,df3["train_loss"],label=f"train",color="mediumslateblue")
ax.plot(x,df3["valid_loss"],label=f"valid",color="mediumslateblue",linestyle='--')
ax.legend()
ax = axes[1]
ax.set_xlabel("epoch")
ax.set_ylabel("accuracy")
ax.plot(x,df3["train_accu"],label=f"train",color="mediumslateblue")
ax.plot(x,df3["valid_accu"],label=f"valid",color="mediumslateblue",linestyle='--')
ax.legend()
fig.tight_layout()
plt.savefig("optimCNN.pdf")
plt.show()

# %% [markdown]
# Consideremos aproximadamente 40 epocas de entrenamiento como un numero óptimo

# %%
def plot_img(data, idx):

    #grafica un ejemplo
    figure = plt.figure(figsize=(4, 4))
    img, label = data[idx]
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
    plt.show()

def show_prediction(example):

    #muestra la prediccion para un ejemplo

    model.eval()
    x, y = test_dataset[example][0], test_dataset[example][1]
    with torch.no_grad():
        pred = model(x.unsqueeze(1).to(device))
    sorted = pred.sort()
    values = sorted.values[0]
    indices = sorted.indices[0]
    print(
        f"Etiqueta correcta: {labels_map[y]}" ,
        end= "\n----------------------\n"
    )
    print("Etiqueta          Probabilidad")
    for v, idx in list(zip(values,indices))[::-1]:
        label_pred = labels_map[idx.item()]
        print(f"{label_pred:13}{v.item():.5f}")

# %%
example = 4321
plot_img(test_dataset, example)
#plt.savefig('pullover.pdf')
show_prediction(example)
# Out:
# Etiqueta correcta: Trouser
# ----------------------
# Etiqueta          Probabilidad
# Trouser      21.13339
# T-Shirt      3.93703
# Dress        -0.69687
# Coat         -5.03083
# Shirt        -7.52805
# Pullover     -10.52989
# Bag          -16.75121
# Sandal       -22.58346
# Sneaker      -33.97128
# Ankle Boot   -35.90971
